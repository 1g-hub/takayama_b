# %%
# !pip install langchain_openai
# !pip install tiktoken
# Out:
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.33 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (0.2.33)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (1.41.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (0.1.99)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.33->langchain_openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain_openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain_openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain_openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.33->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.33->langchain_openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.33->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.33->langchain_openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.0.7)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from pathlib import Path
import copy
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from langchain_openai import ChatOpenAI
import tiktoken

from collections import defaultdict
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
from torch.utils.data import DataLoader, Dataset
from torch import FloatTensor, LongTensor

import sys
sys.path.append('/content/drive/MyDrive/ex2024/')

# colab 関連
from google.colab import files
from google.colab import userdata

os.environ['OPENAI_API_KEY'] = 'NjZiYjBkNjc2MDJlMzIzZmY4MTNlYzg1OlNYWHo1eDdZclpkTkVXRnJLRzNiUGNDRml2YllnSjJB'
os.environ['API_HOST']='https://platform.preferredai.jp'
llm = ChatOpenAI(
    base_url=f"{os.environ['API_HOST']}/api/completion/v1",
    model="plamo-beta",
    streaming=False,
    # other params...,
    max_tokens=2048
)

# %%
def load_jsonl(path: Path | str) -> pd.DataFrame:
    path = Path(path)
    return pd.read_json(path, lines=True)


def load_json(path: Path | str) -> dict:
    path = Path(path)
    with path.open() as f:
        data = json.load(f)
    return data

# %%
# -*- coding: utf-8 -*-
class Args():
    #BERT訓練済みモデル
    bert_pretrained_model_name = "cl-tohoku/bert-base-japanese-v3"
    max_seq_len = 512 #BERT入力列最大値
    batch_size = 32

    seed: int = 42


    sampling_flag = {'train': True, 'val': False, 'test': False}
    sampling_rate = {'train': 0.35, 'val': 1.0, 'test': 1.0}

    #livedoorニュースコーパスデータセットへのパス
    dataset_dir: Path = Path('/content/drive/MyDrive/ex2024/livedoor/datasets/livedoor/')

    #要約辞書保存先
    summary_dict = defaultdict(lambda: defaultdict(list))
    output_model_dir: Path = Path('/content/drive/MyDrive/ex2024/livedoor/datasets/livedoor/summary/')

# %%
def get_summary(batch, batch_size=32):
    res = defaultdict(lambda: defaultdict(list))
    # 使用するモデルに対応するトークナイザを取得
    encoding = tiktoken.get_encoding("cl100k_base")

    # 最大トークン数を設定（例: 4096 - 出力用トークンを残して 2048 トークン）
    input_max_tokens = 1700
    for i in range(batch_size):
        input_tokens = encoding.encode(batch['body'][i])
        num_tokens = len(input_tokens)
        body = batch['body'][i]
        if num_tokens > input_max_tokens:
            # トークンを制限内に収めるためにカット
            input_tokens = input_tokens[:input_max_tokens]
            # トークンを再びテキストに変換
            trimmed_prompt = encoding.decode(input_tokens)
            body = trimmed_prompt
        messages=[
            {"role": "system", "content": "あなたは優秀なAIアシスタントです。"},
            {"role": "user", "content": "以下は「{0}」というタイトルの記事の本文です。内容を要約し、結果のみを出力してください。".format(batch['title'][i])},
            {"role": "user", "content": "{0}".format(body)}
        ]


        res[batch['category-ids'][i]] = llm(messages).content
        print(batch['title'][i][:100])
        print("---------------")
        print(res[batch['category-ids'][i]][:100])
        print("===============")
    return res

# %%
class Experiment():
    def __init__(self, _args: Args):
        #実験設定
        self.args = _args
        self.phase = ['train_1','train_2','train_3','train_4']
        #データローダー
        self.dataloader = defaultdict(lambda: defaultdict(list))
        #データセット(DataFrame)
        self.dataset = defaultdict(lambda: defaultdict(list))
        for p in self.phase:
            self.dataloader[p] = self.load_dataset(phase = p)


    def load_dataset(self, phase):
        path = self.args.dataset_dir / f'{phase}.jsonl'
        original = load_jsonl(path)

        data = original.to_dict(orient="records")
        self.dataset[phase] = pd.DataFrame(data.copy())
        return DataLoader(data, collate_fn=self.collate_fn, batch_size=self.args.batch_size,shuffle=False,num_workers=2,pin_memory=True)

    # カスタムcollate_fnの定義
    def collate_fn(self, batch):
        title = [data['title'] for data in batch]
        body = [data['body'] for data in batch]
        #category-idから元のデータを参照できるようにする
        category_ids = [data['category-id'] for data in batch]
        return {'title': title, 'body': body, 'category-ids': category_ids}

    def category_id2article(self, phase, category_id):
        return self.dataset[phase][self.dataset[phase]['category-id'] == category_id]


    def train(self):
        for phase in ['train_1']:
            print(phase + " start!!\n")
            dataloader_size = len(self.dataloader[phase])
            cnt = 0
            for batch in self.dataloader[phase]:
                print("{}/{}\n".format(cnt,dataloader_size))
                print(batch['title'])
                print(len(batch['title']))
                cnt = cnt + 1
                self.args.summary_dict.update(get_summary(batch, len(batch['title'])))

        # JSONファイルに保存
        with open('/content/drive/MyDrive/ex2024/livedoor/datasets/livedoor/summary/livedoor_summary_plamo_beta_train_1.json', 'w') as json_file:
            json.dump(self.args.summary_dict, json_file)

    def save_model(self):
        torch.save(self.net.state_dict(), self.new_model_path)
        print('\nbest score updated, Pytorch model was saved!! val_acc:{}\n'.format(self.history.best['val']['acc']))


    def run(self):
        print("ex start")
        self.label_distribution()
        self.train()

    def label_distribution(self):
        # ラベルごとのデータ数を集計
        for p in self.phase:
            label_counts = self.dataset[p]['label'].value_counts()
            print(p, label_counts)

# %%
ex = Experiment(_args = Args())
ex.run()
print('---finish---')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# このスマートフォンは高性能CPUを搭載し、HD動画
# ===============
# Peachyアプリアンケートへのご協力、ありがとうございました!
# ---------------
#  Peachyアプリのユーザーアンケートの結果、多くのユーザーが記事の増加を希望し、特に恋愛コラム、美容、レシピ、ダイエット、占いに関する内容を求めていることが分かりました。また、アプリのバグや強制終
# ===============
# iPhoneで作るビジネス文書、動画のムダをトリミング iPhone活用術【知っ得!虎の巻】
# ---------------
#  与えられた文章を要約します。
#
# iPhoneをビジネスに活用する方法が掲載された記事の要約は以下の通りです。
#
# ・子どもがiPhoneを使う際、アプリの機能制限を設定するなど、いたずらや危険なサイト
# ===============
# いよいよ明日!JAXAが行う「みんなで皆既月食を観察しようキャンペーン」【話題】
# ---------------
#  要約:
#
# 日本のJAXA宇宙教育センターが「みんなで皆既月食を観察しようキャンペーン」を開始し、明日の皆既月食の観測写真やスケッチを募集しています。太平洋側では晴天が期待され、絶好の観察日和となりそ
# ===============
# 「メガロス」1日無料体験チケットをブロガー限定プレゼント
# ---------------
#  メガロスがブロガー限定で、施設の1日無料体験チケットをプレゼントしている。メガロスは、関東を中心とした国内最大級のスポーツクラブで、設備やスタッフの対応に定評がある。夏が近づいているこの機会に、実際
# ===============
# 第24回東京国際映画祭作品ガイド<香川京子と巨匠たち部門>
# ---------------
#  香川京子と巨匠たち部門で上映される作品の一覧です。各作品の内容を簡潔にまとめました。
#
# 「近松物語」：京都の大店の手代と奉公人の不義密通をめぐる悲恋物語を、巨匠・溝口健二が映画化した傑作。
#
# 「王将
# ===============
# 猫ひろしに負けたカンボジア選手に「何も言う資格無い」との声も
# ---------------
#  この記事では、カンボジア国籍を取得しロンドンオリンピックにカンボジア代表として出場した猫ひろしに対する批判の声がネット掲示板や著名人から上がっていると報じています。主な批判内容は、猫ひろしがカンボジ
# ===============
# 毎日の生活の中でお小遣いを増やす方法とは?
# ---------------
#  要約: 独身女性は自由に使えるお金が少ないため、ポイントサイトを利用してお小遣いを増やすことができます。チャンスイットというポイントサイトは、有名なメーカーや店舗と提携しているため、女性向けの商品や
# ===============
# 敗者は去れ? 再挑戦を認めるか認めないかで荒れるクラウドファンディング「studygift」
# ---------------
#  この記事では、学費支援プラットフォーム「studygift」のローンチと、それに関連する批判や炎上について述べられています。記事の要点をまとめると以下の通りです。
#
#
# ・studygiftは経済的な
# ===============
# どこに着目して情報収集すればいいかが分かる「顧客の顧客」リサーチトレーニング - プロフェッショナルスキル入門 vol.05 【質問力編】
# ---------------
#  記事では、ビジネススキルの中でも質問力に焦点を当てています。特に、川上慎市郎氏の「顧客の顧客」リサーチトレーニングに関する内容が紹介されています。以下に要約します。
#
# 質問力を高めるためには、事前の
# ===============
# 声に反応! 東芝の「VoiPY」で電化製品を声でコントロール【売れ筋チェック】
# ---------------
#  東芝は12月上旬に声で家電を操作できるボイスコントローラ「VOiPY RB-VC01」を発売します。これは既に発売しているエアコン「大清快VOiCE NDRシリーズ」のボイスコントローラと同じもので
# ===============
# 「暑い」といえば涼しくなる!世界初の声に反応するエアコン「大清快VOiCE NDRシリーズ」が東芝から発売
# ---------------
#  東芝が「大清快VOiCE NDRシリーズ」というエアコンを発売します。このエアコンの特徴は音声認識機能を搭載しており、「暑い」「節電」などの音声に反応して動作を変化させる点です。マイクとスピーカーを
# ===============
# 感謝を込めて贈りたい!歴女とっておきの”幕末ショコラ”
# ---------------
#  この記事では、日本橋三越本店にて限定発売される「幕末ショコラ」の紹介がされています。
# 「幕末ショコラ」は、坂本龍馬、土方歳三、西郷隆盛、ペリーをイメージして作られた4種類のチョコレートで、それぞれの
# ===============
# 快適なスマホライフのための必須アプリ
# ---------------
#  提示された文章を要約します。
#
# 日本人の半数近くが持つスマートフォンの出荷台数が、従来型の携帯電話の出荷台数を昨年初めて上回った。
# インターネットや音楽、動画、ゲームなどを楽しめるスマホは、自宅・外
# ===============
# 人工知能からHCIへ グーグルの生みの親が語る、コンピューターと人の関係(1)【テレスコープマガジン】
# ---------------
#  この記事によると、ラリー・ページの恩師であるテリー・ウィノグラード氏は最初は人工知能の研究をしていたが、人間とコンピューターの関係についての興味が強くなり、ヒューマン・コンピューター・インタラクショ
# ===============
# 【Sports Watch】浅田真央の逆転優勝、荒川キッパリ“可能です”
# ---------------
#  この記事では、バンクーバーオリンピックの女子フィギュアスケートSPが終わり、1位のキム・ヨナ選手と2位の浅田真央選手の得点差は4.72という内容を報じています。トリノオリンピック金メダリストの荒川静
# ===============
# 【今週のオススメ「iPhoneアプリ」特集:2012年6月10〜23日編】
# ---------------
#  以下は先の文章の要約です。
#
# この週のオススメiPhoneアプリの紹介記事で、以下のアプリが紹介されました。
#
# ・シンプルな2画面画像ビューワー「TwinViewer」
#
# ・ラッピング方法をイラスト
# ===============
# 国内主要空港でのサポートを拡充!テレコムスクェア新オープン&リニューアル!
# ---------------
#  国内主要空港でのサポート強化のため、株式会社Preferred ElementsのAIアシスタント「PLaMo」がお伝えする今回のニュースは以下の通りです。
#
# 株式会社Preferred Eleme
# ===============
# 働き女子のしあわせカラダづくりを応援するアプリでキレイとご褒美をゲット!?
# ---------------
#  この記事は、「au Smart Sports Run&Walk」という、auケータイで人気のスポーツサポートサービスのAndroidアプリ版がリリースされたことを報じています。このアプリは、ランニン
# ===============
# 感動の上演再び! 「ゼッド」で神秘的でリリカルな世界を体験しよう
# ---------------
#  シルク・ドゥ・ソレイユのゼッドの公演が、3月11日に発生した東日本大震災により中断していましたが、4月23日より再開されることになりました。世界22ヶ国から集まった70名のアーティストが再集結し、エ
# ===============
# 17/47
#
# ['オリオン電機から発売! USB接続HDDへ録画対応液晶テレビ', '武井咲とクリスマスを一緒に過ごし、彼女の誕生日を祝う方法', '【Sports Watch】ソフトバンク・内川「“お前、早くから泣き過ぎだろ”という指摘がきまして・・・」', '2D動画を3Dに変換!Webから動画ダウンロードもできるソフトのレビューアー募集開始', '待ってましたのGPUが発売!新型Radeon HD搭載カードが続々登場中', '香川真司、自身の移籍報道を語る', '老若男女が熱狂したディズニーのミュージカル映画、アカデミー主題歌賞を受賞', '経験者が語る「職場恋愛のススメ」', '世界的に盛り上がる、“旧車カスタム”というカルチャー', '間違いだらけのお金の使い方/「女って面倒」と思った瞬間など−【ライフスタイル】週間ランキング', '竜の巣?  これが...? 富士山上空を覆う巨大雲が話題に', '過去最高のサウンド品質かも! 音もナイスなRetina MacBook Pro 【デジ通】', '【Office Scope vol.08】オシャレでポップな空間が、オフィスを「楽しく仕事をする」場所に(株式会社Stardust Communications)', 'やっぱり男も“顔”ですか?', '【週末映画まとめ読み】栗山千明「今の平和な世界が大好きなんです」', 'GALAXY TabもiPadも家電も充電できる!万能高容量ポータブルバッテリー【イケショップのレア物】', '熱心な女性ゴルファーが持つクラブの悩みとは?', '「はやぶさ」のグルメ登場! うな重にカレーにケーキまで', 'クルマ色話 vol.4【ホンダ・フィットシャトル】微妙に男心をくすぐるOLみたいなクルマ!?', '“職場恋愛”は本当にドラマチック? 才職兼美スタッフ座談会', '【ニュース】「OLYMPUS Viewer 2」のバージョンアッププログラム明日公開', '処世術はSMに学べ!', '女子力も上がる!? 大人のシール事情!', 'NTTドコモ、Xperia PLAYやXperia ray、Xperia acro、Xperia arc、F-12CにおいてAndroid 4.0 ICSへのOSバージョンアップを断念', '日本代表敗戦、セルジオ越後氏は「ベストメンバーでなければこの程度」', 'クリスマスにはやっぱり定番ノエル。だけど特別感も欲しい!', '普通の中学で学んだ程度でした!孫社長が明かした若き日の英語力', '作りたいのは碁盤目のような表ばかりじゃない! Wordの表を自由自在に編集【知っ得!虎の巻】', 'NTTドコモ、LUMIX Phone P-02Dにタッチパネルの感度設定を追加するなどでソフトウェア更新を提供開始', '『ワイルド・スピードMEGA MAX』に学ぶ“超肉食”のススメ!', '【話題】ケータイでテレビを見るのは当たり前「ひかりTV」が年内にモバイル専用プラン開始', '女を磨く“植物学”入門 Vol.1 ′′心のくすみ′′を取る!いけ花']
# 32
# オリオン電機から発売! USB接続HDDへ録画対応液晶テレビ
# ---------------
#  オリオン電機は、USB接続したHDDへの録画機能を備えた液晶テレビ、22型の「DU221-B1」と19型の「DU191-B1」を発売しました。これらのテレビには地上デジタル放送と地上アナログ放送のチ
# ===============
# 武井咲とクリスマスを一緒に過ごし、彼女の誕生日を祝う方法
# ---------------
#  以下は文章の要約です。
#
# 12月25日に、武井咲の歌手デビューシングル「恋スルキモチ」のリリース記念イベントが開催されます。イベントには、通常盤、初回盤A、または初回盤Bの購入で参加できます。初回盤
# ===============
# 【Sports Watch】ソフトバンク・内川「“お前、早くから泣き過ぎだろ”という指摘がきまして・・・」
# ---------------
#  福岡ソフトバンクホークスが、埼玉西武ライオンズとの試合に勝利し、2年連続17回目のリーグ優勝を果たしました。試合後、ソフトバンクの選手である内川聖一がテレビ番組に出演し、涙を流したことについて質問さ
# ===============
# 2D動画を3Dに変換!Webから動画ダウンロードもできるソフトのレビューアー募集開始
# ---------------
#  zigsowは本日、Wondershare社の動画変換ソフト『スーパーメディア変換!(Win版)』のレビューアー募集を開始した。このソフトは高速な2D動画から3D動画への変換機能を備え、動画・音楽フ
# ===============
# 待ってましたのGPUが発売!新型Radeon HD搭載カードが続々登場中
# ---------------
#  この記事では、AMD社のグラフィックカードの新製品、Radeon HD 7870とRadeon HD 7850が今月発売されることが発表されました。これらの製品は、ミドルレンジからハイエンドの性能を
# ===============
# 香川真司、自身の移籍報道を語る
# ---------------
#  「NEWS ZERO」がドイツ・ボルシア・ドルトムントに所属するサッカー選手の香川真司にインタビューを行った。香川は来シーズン以降の移籍について明言を避けたが、将来についてはしっかり考えており、オフ
# ===============
# 老若男女が熱狂したディズニーのミュージカル映画、アカデミー主題歌賞を受賞
# ---------------
#  映画「ザ・マペッツ」のオリジナル・ソング「マン・オア・マペット」がアカデミー主題歌賞を受賞しました。この映画は、人間とマペットが共存する世界が舞台のミュージカルで、主演のゲイリーとウォルターが歌うバ
# ===============
# 経験者が語る「職場恋愛のススメ」
# ---------------
#  記事の要約は下記のとおりです。
#
#
# 「出会いがない」「いい男がいない」と言う女性は、男性に対し厳しい目で見る傾向にある。職場恋愛を切り捨てるのは、自分から可能性を狭めているようなものだ。
#
# 実際に、
# ===============
# 世界的に盛り上がる、“旧車カスタム”というカルチャー
# ---------------
#  与えられた文章の要約を以下に示します。
#
# 旧車に最新の技術やデザインを取り入れてカスタムする「旧車カスタム」が世界的に注目を集めています。レストモッドやハイテックといったカスタムスタイルが確立され、
# ===============
# 間違いだらけのお金の使い方/「女って面倒」と思った瞬間など−【ライフスタイル】週間ランキング
# ---------------
#  以下のように要約できます。
#
# 先週のライフスタイルカテゴリのアクセスランキングは、以下の通りです。
#
# 1位:クレジットカードの間違った使い方に関する記事の後編
#
# クレジットカードの間違った使い方のう
# ===============
# 竜の巣?  これが...? 富士山上空を覆う巨大雲が話題に
# ---------------
#  富士山の上空に巨大な雲が発生し、その様子がスタジオジブリの映画「天空の城ラピュタ」に出てくる「竜の巣」に似ていると、Twitter上に多くの写真が投稿され話題になりました。気象学的な詳細は不明ですが
# ===============
# 過去最高のサウンド品質かも! 音もナイスなRetina MacBook Pro 【デジ通】
# ---------------
#  この記事では、Retina MacBook Proのスピーカー品質が高く、過去のMacBookシリーズや他社のノートパソコンと比較しても優れていることが述べられています。ノートパソコンのスピーカーの
# ===============
# 【Office Scope vol.08】オシャレでポップな空間が、オフィスを「楽しく仕事をする」場所に(株式会社Stardust Communications)
# ---------------
#  この記事は、株式会社Stardust Communicationsのオフィス訪問を通じて、同社のオフィスデザインと働き方について取り上げたものです。以下に要点をまとめます。
#
#
# ・株式会社Stard
# ===============
# やっぱり男も“顔”ですか?
# ---------------
#  要約すると、この記事では「結婚相手に求める条件」として、女性たちが顔の良い男性を重視するかどうかを探っています。記事内の例では、性格や優しさ、安定した仕事といった条件が上位に挙げられ、必ずしも顔の良
# ===============
# 【週末映画まとめ読み】栗山千明「今の平和な世界が大好きなんです」
# ---------------
#  今週の主な映画ニュースをまとめます。
#
# 栗山千明は映画「ドラゴンエイジ-ブラッドメイジの聖戦-」で、強い女性を演じることについて語っています。また、AKB48の篠田麻里子は映画「TIME/タイム」の
# ===============
# GALAXY TabもiPadも家電も充電できる!万能高容量ポータブルバッテリー【イケショップのレア物】
# ---------------
#  記事の要約:
#
# 「PowerBank 10000mAh (5V/9V/12V出力)」という高容量ポータブルバッテリーが紹介されています。このバッテリーは大容量(10000mAh)でありながら、充電時
# ===============
# 熱心な女性ゴルファーが持つクラブの悩みとは?
# ---------------
#  本文の要約:
#
#  本文では、上達志向の強い女性ゴルファーが直面する問題が取り上げられています。それは、スイングが上達するにつれて、一般的な女性用ゴルフクラブでは物足りなくなってしまうことです。しかし
# ===============
# 「はやぶさ」のグルメ登場! うな重にカレーにケーキまで
# ---------------
#   この記事では、相模原市の淵野辺駅周辺商店街による「はやぶさグルメで地元からJAXAにエールを送ろう」という企画を伝えています。JAXAの関係者に試食してもらうために、各店舗が「はやぶさ」や「宇宙」
# ===============
# クルマ色話 vol.4【ホンダ・フィットシャトル】微妙に男心をくすぐるOLみたいなクルマ!?
# ---------------
#  要約すると以下のようになります。
#
# 小沢コージと吉田由美がホンダのフィットシャトルについて対談しています。小沢はフィットシャトルの価格と出来について評価していますが、吉田は車内の温度上昇やドアの質感
# ===============
# “職場恋愛”は本当にドラマチック? 才職兼美スタッフ座談会
# ---------------
#  記事では、職場恋愛のリアルについて、座談会が行われました。職場恋愛の定番的なイメージである「エレベーターでの出会い」などのシチュエーションには、やはり女性は憧れるようです。仕事が忙しい人ほど、職場で
# ===============
# 【ニュース】「OLYMPUS Viewer 2」のバージョンアッププログラム明日公開
# ---------------
#  デジタルカメラ「OLYMPUS PEN」などのアートフィルターを使用したRAW現像のバージョンアップが、11時より行われます。今回のバージョンアップでは、未搭載のアートフィルターをソフトウェアで楽し
# ===============
# 処世術はSMに学べ!
# ---------------
#  提示された記事を要約し、結果のみ出力します。
#
#
# 異業種交流女子会で、秘書室勤務のカオルさん(33歳)が自分はSだと発言しました。M体質の人が周りに集まることから、自分はS要素が強いと自己分析してい
# ===============
# 女子力も上がる!? 大人のシール事情!
# ---------------
#  この記事では、文具店や雑貨店でシールが人気を集めていることを伝えています。シールは様々な種類があり、記事では主に大人の女性がシールを集めて、カードやアルバム作りに活用していることが紹介されています。
# ===============
# NTTドコモ、Xperia PLAYやXperia ray、Xperia acro、Xperia arc、F-12CにおいてAndroid 4.0 ICSへのOSバージョンアップを断念
# ---------------
#  NTTドコモは、「Xperia PLAY SO-01D」、「Xperia ray SO-03D」、「Xperia acro SO-02C」、「Xperia arc SO-01C」、「F-12C」のA
# ===============
# 日本代表敗戦、セルジオ越後氏は「ベストメンバーでなければこの程度」
# ---------------
#  北朝鮮戦の結果: 日本代表は北朝鮮代表に0-1で敗北した。
#
# 要約: 北朝鮮で行われたW杯3次予選の第5戦で、日本代表は北朝鮮代表に敗れた。日本代表のアルベルト・ザッケローニ監督は厳しい環境の中での
# ===============
# クリスマスにはやっぱり定番ノエル。だけど特別感も欲しい!
# ---------------
#  記事の要約:
#
# ホテルのクリスマスケーキの中でも、特にクリスマスにおすすめなのが、ホテルならではの上質な素材を使った、ブッシュ・ド・ノエルです。
#
# ホテルメトロポリタンの「カラメル・ノエル」は、ヘー
# ===============
# 普通の中学で学んだ程度でした!孫社長が明かした若き日の英語力
# ---------------
#  与えられた記事の内容を要約し、結果のみ出力します。
#
# 孫正義がTwitter上で若き日の英語力について語ったところ、多くの反響がありました。孫は中学時代に留学しましたが、英語力は普通の中学で学んだ程
# ===============
# 作りたいのは碁盤目のような表ばかりじゃない! Wordの表を自由自在に編集【知っ得!虎の巻】
# ---------------
#  Wordで、列数または行数を指定してセルを均等に分割するには、表を選択して「レイアウト」タブの「セルの分割」をクリックし、分割したい列数または行数を指定して「OK」をクリックします。これにより、指定
# ===============
# NTTドコモ、LUMIX Phone P-02Dにタッチパネルの感度設定を追加するなどでソフトウェア更新を提供開始
# ---------------
#  NTTドコモは5日、LUMIX Phone P-02Dのソフトウェア更新を開始しました。更新内容は、カメラ撮影後のプレビューで稀にフリーズする不具合と、microSDXCカード使用時の不具合の修正、
# ===============
# 『ワイルド・スピードMEGA MAX』に学ぶ“超肉食”のススメ!
# ---------------
#  「『ワイルド・スピードMEGA MAX』に学ぶ“超肉食”のススメ!」の記事の要約は以下の通りです。
#
# 「ワイルド・スピードMEGA MAX」は全世界63カ国でNo.1を記録し、シリーズ最高のオープニ
# ===============
# 【話題】ケータイでテレビを見るのは当たり前「ひかりTV」が年内にモバイル専用プラン開始
# ---------------
#  要約:「ひかりTV」がモバイル専用プランを年内に提供し始める。月額350円の「すまほエントリープラン」と月額1000円の「すまほバリュープラン」があり、スマートフォンやタブレット端末から直接契約し、
# ===============
# 女を磨く“植物学”入門 Vol.1 ′′心のくすみ′′を取る!いけ花
# ---------------
#  この記事は、植物の美しさと癒しの力に着目し、女性が植物の恩恵を受けることで内面から美しくなることを提案しています。「インタビュー編」では専門家に植物の活用法を学び、「レッスン編」ではいけばなを通じて
# ===============
# 18/47
#
# ['外資系半導体メーカー 営業マネージャー「現状に満足したら終わり」 - 年収1000万円プレイヤー図鑑 vol.3', '【隠れた注目機種!?コンパクトなほぼ全部入りXiスマホ「Optimus it L-05D」特集】', 'ThinkPadをNECで生産へ 2012年秋より日本で試験生産【デジ通】', '[穫れたて現地情報]BBクリームは夏のマストアイテム! 限定版もチェックすべし!', '赤裸々な女の生態を描く「祝女」が帰ってくる!', '若者の間で社会現象を巻き起こした名作『池袋ウエストゲートパーク』がBeeマンガに', '坂下千里子、イケメン俳優のキスにメロメロ', '桑田真澄氏、DeNAべスターズ監督&巨人お家騒動に言及', 'ツイッター上で週刊新潮にブチギレした橋下徹氏にネットでは賛否両論', 'テレビ録画もガラパゴス化 日本にしか無いテレビ録画機市場【デジ通】', '女医が教えるオンナの体のウソホント vol.6「精子にまつわるウソホント」Presented by ゆるっとcafe', 'KDDI、Android 4.0 ICS搭載スマートフォン「URBANO PROGRESSO」を5月30日に発売開始!世界初スマートソニックレシーバー搭載', '将来のために、何かあったときのために貯金&運用をする独女たち', 'マット・デイモンとスカーレット・ヨハンソンが共演、世界を感動で包んだ実話を映画化', '平野綾と“ファイナルファンタジー”の魅力がタッグを組む', 'これなら欲しい? PS Vitaのニセモノが海外で登場、名前は「PS Vista」【話題】', '自分にぴったりということ', 'ウィキ・ペディアにも負けない!? キャプテン・アメリカの戦力を徹底解剖!', 'なんだ、そうだったのか!Googleロゴが四角い建築である理由', '夏と言えば朝顔! 小学生時代を思い起こさせるアサガオ観察日記ツイート', '新月を狙う! この夏は天文写真の撮影に挑戦!【カメラ生活】', '【オトナ女子映画部】アラサーアイドルがヒーローに!安っぽさやくだらなさを楽しむ『エイトレンジャー』', 'バンギャの切なく重い愛!? Presented by ゆるっとcafe', '野菜でキレイになる! 自宅でパックが簡単に作れるフェイシャルパックメーカー【モテる家電】', '「3秒」で恋愛対象外? 残念なイケメン君が増殖中!?', 'アウトドア&モバイル移動放送局【ビデオSALON】', '【週末映画まとめ読み】ミス青山学院が体を張って東京国際映画祭をPR <10月22日号>', '『マダガスカル3』で声優の続投が決定、柳沢慎吾が“ひとり警視庁24時”', '【Sports Watch】人気女子ゴルファー、苦難の時代を語る', '【力説自動車.web】第2回:被災地のクルマたち', '新しい発想を得ることができる「否定文作成トレーニング」 - プロフェッショナルスキル入門 vol.03 【発想力編】', '【週末映画まとめ読み】『アベンジャーズ』ワールドプレミアで日米最強女優がそろい踏み']
# 32
# 外資系半導体メーカー 営業マネージャー「現状に満足したら終わり」 - 年収1000万円プレイヤー図鑑 vol.3
# ---------------
#  記事では、外資系半導体メーカーの営業マネージャーである山岡氏の業務やプライベートについて紹介されています。山岡氏は、USやヨーロッパなどの拠点と連携しながら最先端の半導体を提案する業務に携わっており
# ===============
# 【隠れた注目機種!?コンパクトなほぼ全部入りXiスマホ「Optimus it L-05D」特集】
# ---------------
#  記事の要約:
#
# 「Optimus it L-05D」は、コンパクトでありながらXiやおサイフケータイ、ワンセグ、防水などの機能を備えた全部入りスマホで、レスポンスの良さも好評です。また、ディスプレイ
# ===============
# ThinkPadをNECで生産へ 2012年秋より日本で試験生産【デジ通】
# ---------------
#  要約するとこの記事の内容は、NECレノボ・ジャパングループの元で運営されているレノボとNECにおいて、レノボの人気ノートパソコンThinkPadの一部モデルを、NECの米沢事業所で試験生産することが
# ===============
# [穫れたて現地情報]BBクリームは夏のマストアイテム! 限定版もチェックすべし!
# ---------------
#  この記事では、夏の紫外線対策におすすめのBBクリームについて紹介されています。まず、BBクリームが多機能で、時短メイクに適していることが説明されています。そして、韓国の明洞で人気のあるBBクリームが
# ===============
# 赤裸々な女の生態を描く「祝女」が帰ってくる!
# ---------------
#  この記事では、NHKの番組「祝女」がシーズン2として9月30日から放送開始することが発表されています。「祝女」は、女性の生態を赤裸々に描いたショートドラマで、女性たちの本音やあるあるエピソードが満載
# ===============
# 若者の間で社会現象を巻き起こした名作『池袋ウエストゲートパーク』がBeeマンガに
# ---------------
#  ドラマ化され社会現象を巻き起こした名作「池袋ウエストゲートパーク」が、ケータイ専用放送局「BeeTV」のBeeマンガで配信されるようになります。主役のマコト役の声優は遠藤要さん、マコトの同級生でギャ
# ===============
# 坂下千里子、イケメン俳優のキスにメロメロ
# ---------------
#  この記事の要約は以下の通りです。
#
# ドラマ『クリミナル・マインド』のシーズン5のDVDリリースを記念して、Dr.リード役のマシュー・グレイ・ギュブラーとデレク・モーガン役のシェマー・ムーアが来日し、
# ===============
# 桑田真澄氏、DeNAべスターズ監督&巨人お家騒動に言及
# ---------------
#  提示された文章の要約は以下のとおりです。
#
# プロ野球解説者の野村克也氏と桑田真澄氏の対談の中で、野村氏が巨人のお家騒動について桑田氏に質問し、桑田氏はOBとして問題解決を望んでいると回答しました。ま
# ===============
# ツイッター上で週刊新潮にブチギレした橋下徹氏にネットでは賛否両論
# ---------------
#  要約すると、橋下徹氏が週刊新潮の電話番号などが含まれた取材依頼書の内容をツイッター上で公開し、週刊新潮の取材姿勢を批判しました。これに対し、ネット上では賛否両論が起こり、橋下氏を擁護する意見もある一
# ===============
# テレビ録画もガラパゴス化 日本にしか無いテレビ録画機市場【デジ通】
# ---------------
#  この記事では、海外では日本でよく見られるような録画機器や録画文化が存在しないことを述べています。海外では、テレビ番組の再放送やオンライン配信が一般的であるため、録画機器の需要が低く、市場も小さいとさ
# ===============
# 女医が教えるオンナの体のウソホント vol.6「精子にまつわるウソホント」Presented by ゆるっとcafe
# ---------------
#  記事の要約:
#
# この記事では、女性の体に関する様々な都市伝説を検証しています。主に精子に関するウワサとして、高熱で精子が死ぬという説や、精子をコーラで洗うと妊娠しないという説が取り上げられています。
# ===============
# KDDI、Android 4.0 ICS搭載スマートフォン「URBANO PROGRESSO」を5月30日に発売開始!世界初スマートソニックレシーバー搭載
# ---------------
#  Android 4.0 Ice Cream Sandwichを搭載したスマートフォン、URBANO PROGRESSOが2012年5月30日にKDDIと沖縄セルラーから発売されます。防水・防塵、おサ
# ===============
# 将来のために、何かあったときのために貯金&運用をする独女たち
# ---------------
#  記事の内容を要約します。
#
# ボーナスをもらったばかりの佐智子さん(35)は、これまで貯金をしてこなかったが、将来への不安から、毎月2万円の定期預金を始めることにしました。他の独身女性の方々も貯金や運
# ===============
# マット・デイモンとスカーレット・ヨハンソンが共演、世界を感動で包んだ実話を映画化
# ---------------
#  マット・デイモンとスカーレット・ヨハンソンが共演する「幸せへのキセキ」は、実話に基づいたストーリーで、半年前に妻を亡くした男性が家族と共に動物園を再建する物語です。予告映像では、主人公ベンジャミンの
# ===============
# 平野綾と“ファイナルファンタジー”の魅力がタッグを組む
# ---------------
#  『劇場版 FAIRY TAIL -鳳凰の巫女-』のエンディング主題歌が、人気声優・平野綾演じるルーシィ・ハートフィリアが歌う「タイトル未定」に決定しました。作詞は松井五郎、作曲は植松伸夫が担当してお
# ===============
# これなら欲しい? PS Vitaのニセモノが海外で登場、名前は「PS Vista」【話題】
# ---------------
#  昨年末に発売された「PS Vita」のニセモノ「PS Vista」が、タイで販売されていると話題になっています。見た目は似ていますが、中身はまるで別物で、ゲームも違法なものが内蔵されています。しかし
# ===============
# 自分にぴったりということ
# ---------------
#  提示された記事の要約は下記の通りです。
#
#
# 今年の就職活動の状況は厳しく、100社受けても書類選考で落とされる学生もいます。企業で採用活動をしている金子氏は、自分に合う仕事を探すよりも、まずは働いて
# ===============
# ウィキ・ペディアにも負けない!? キャプテン・アメリカの戦力を徹底解剖!
# ---------------
#  提供された文章を要約します。
#
# キャプテン・アメリカとして活躍するスティーブ・ロジャースは、小柄で病弱であったが、軍の超人計画に志願し、身体能力を向上させた。しかし、それ以前の彼の身体能力は以下の通
# ===============
# なんだ、そうだったのか!Googleロゴが四角い建築である理由
# ---------------
#  Googleのロゴが建築家ミース・ファン・デル・ローエの誕生日を記念して、彼のモダニズム建築をイメージしたデザインに変更されたことを伝えています。
# ===============
# 夏と言えば朝顔! 小学生時代を思い起こさせるアサガオ観察日記ツイート
# ---------------
#  小学生時代の夏休みの思い出として、ラジオ体操やプール、花火やキャンプなどの遊びを挙げ、朝顔やひまわりの観察日記が宿題として出されていたことを述べています。子供は夏休みの始めに宿題を終わらせることなく
# ===============
# 新月を狙う! この夏は天文写真の撮影に挑戦!【カメラ生活】
# ---------------
#  ビデオエディター志望の小島暢華さんが、天体写真の撮影に挑戦した経験を記事にしています。小島さんは、光害の影響を受けない場所を求めて、ブリスベン郊外のMoogerah湖へ行きましたが、野生動物の飛び出
# ===============
# 【オトナ女子映画部】アラサーアイドルがヒーローに!安っぽさやくだらなさを楽しむ『エイトレンジャー』
# ---------------
#  記事では、関ジャニ∞のメンバーが出演する映画「エイトレンジャー」について紹介しています。映画は、2035年の荒廃した近未来都市を舞台に、メンバーがヒーロー「エイトレンジャー」となって活躍するアクショ
# ===============
# バンギャの切なく重い愛!? Presented by ゆるっとcafe
# ---------------
#  この文章では、バンギャとはヴィジュアル系バンドが好きな女の子を指し、「バンドギャル」を略した「バンギャ」と呼ばれることが多いことが説明されています。世間からのバンギャのイメージはあまり良くなく、「病
# ===============
# 野菜でキレイになる! 自宅でパックが簡単に作れるフェイシャルパックメーカー【モテる家電】
# ---------------
#  この記事では、自宅で簡単にオリジナルのフェイシャルパックを作ることができる美容家電「フェイシャルパックメーカー FuFuFu」が紹介されています。この商品では、野菜や果物を使って自分好みのパックを作
# ===============
# 「3秒」で恋愛対象外? 残念なイケメン君が増殖中!?
# ---------------
#  この記事では、「3秒イケメン」という言葉が紹介されています。「3秒イケメン」とは、見た目の良い男性のことを指していますが、話してみると「なんだか変」、「会話がかみ合わない」などといった理由から、恋愛
# ===============
# アウトドア&モバイル移動放送局【ビデオSALON】
# ---------------
#  提供された記事の内容を要約すると、次のようになります。
#
# ビデオサロンの2月号では、屋外での配信システムを取り上げています。特に、CerevoのLiveShellやRolandのVR-3をベースにし
# ===============
# 【週末映画まとめ読み】ミス青山学院が体を張って東京国際映画祭をPR <10月22日号>
# ---------------
#  記事の主旨は、映画に関する情報のまとめです。特に、東京国際映画祭の特集、映画ランキング、映画の新作情報、映画関連のイベントやプレゼントキャンペーンなどが取り上げられています。また、映画に関するインタ
# ===============
# 『マダガスカル3』で声優の続投が決定、柳沢慎吾が“ひとり警視庁24時”
# ---------------
#   この記事では、映画「マダガスカル3」で前作に引き続き声優を務める俳優陣について述べられています。声優には玉木宏、柳沢慎吾、高島礼子、岡田義徳、おぎやはぎが起用されており、それぞれが演じる動物たちが
# ===============
# 【Sports Watch】人気女子ゴルファー、苦難の時代を語る
# ---------------
#  記事の内容を要約します。
#
# 日本の女子プロゴルファーである諸見里しのぶと有村智恵は、貧乏だった下積み時代のエピソードを披露しました。諸見里しのぶは賞金が少ない学生時代に、遠征にかかる費用を節約するた
# ===============
# 【力説自動車.web】第2回:被災地のクルマたち
# ---------------
#  この記事は、2006年に出版された自動車に関する著書の復活版の一部として、被災地の様子と自動車について語られています。著者の金子浩久と小沢コージが、東日本大震災の被災地である岩手と宮城を訪れ、津波で
# ===============
# 新しい発想を得ることができる「否定文作成トレーニング」 - プロフェッショナルスキル入門 vol.03 【発想力編】
# ---------------
#  この記事では、発想力を高めるための2つのトレーニングが紹介されています。
#
# まず、「否定文作成トレーニング」です。これは、常識や前提条件を疑い、新たな発想を生み出すためのトレーニングです。具体的な手
# ===============
# 【週末映画まとめ読み】『アベンジャーズ』ワールドプレミアで日米最強女優がそろい踏み
# ---------------
#  以下に、与えられた記事の要約と、結果を出力します。
#
#
# 先週末の映画ランキングでは「劇場版 SPEC〜天〜」が初登場で首位を獲得し、これまで5週連続でトップだった「ドラえもん のび太と奇跡の島」は2
# ===============
# 19/47
#
# ['ランクづけに見る独女たちのプライド', '子供の一瞬の表情も逃さない!「EX-ZR300」開封レポート', 'もはや格闘ドラマ? 松潤主演の「ラッキーセブン」は今後が楽しみな初回16.3%【話題】', '気になる妊娠のこと「つわりって辛いですか?」', 'ウォンビンインタビュー「お互い寄り添うように助け合う愛もある」直筆サイン特別プレゼント', '「浅田真央が“4キロ激ヤセ”」と女性自身', 'ジーコ、本田圭佑について「私がCSKAの監督だった時・・・」', '『東京ガールズコレクション 2012』が1/7よりチケット先行発売', '【終了しました】食べるスキンケアで冬の枯れ肌を撃退!『美人食材を食べて1ヶ月できれいに! ビューティーレシピ』を5名様にプレゼント', '独女的映画レビュー vol.13 『幸せの始まりは』', '′′20代の4割が童貞・処女′′にネット騒然', 'デキる男はココが違う!超一流スパイが教える女を落とすテクニック', '【終了しました】幸せを運んでくれるかも? 南米パラグアイの銀細工ピアスを3名様にプレゼント', '巨大都市ニューヨーク各所に出現した“どこでもドア”', '元「モーニング娘。」高橋愛に熱愛スクープ。ファンから悲痛な叫び', '六本木で「スター・ウォーズ」の祭典、ジョージ・ルーカスの娘も登場', '2人の“エリカ様”が女優復帰会見でEXILEダンス披露', '【韓国ニュース】「眞露」が世界一も韓国ネットユーザーは意外な反応', '「平日休みの彼女とスケジュールがあわない」 - 辛口説教部屋 vol.31', 'うっとうしい? うらやましい? 自分好きな人', '【恋愛】恋の勝ち組になる!週間ランキング(20120326-20120401)', 'バイキングという食文化をどう思う?', '【特集/JOURNEY】 刺激的で優しいアラブの国へ (7/8)', '「MIHARAYASUHIRO」のショーをフォトレポート/東京コレクション・ウィーク', 'スパイからロック・スターへ転身? トムがミュージカル映画に初挑戦した予告映像が公開', '反日映画か? 『アジアの純真』日本公開に物議', 'グーグルプラスで衝撃! AKB前田敦子が顔面センターをついに持ちネタ化し好感度アップ【話題】', '「重たい女」にならないためには?', '歴代アメコミ・ヒーローを徹底比較! 原点ヒーロー“キャプテン・アメリカ”の実力を測る', '「転職できる力」養成講座 その5 : 『東大卒でも赤字社員 中卒でも黒字社員』', 'iPhoneの同期に要注意! 家族団らんが崩壊したとの報告あり【話題】', 'ただの女友達と好きな女の境界線']
# 32
# ランクづけに見る独女たちのプライド
# ---------------
#  与えられた記事の内容を要約し、結果のみを以下に示します。
#
# 女性にとって「いい男」とは、優しくて包容力があり、ぐいぐいと引っ張ってくれて、結婚を決断できる人である。
# 「いい男」は早くに結婚してしまう
# ===============
# 子供の一瞬の表情も逃さない!「EX-ZR300」開封レポート
# ---------------
#  与えられた文章の要約は以下の通りです。
#
#
# カシオ計算機は、デジタルカメラ“EXILIM”の新製品として、広角24mm/光学12.5倍ズームレンズを搭載した最上位モデル『EX-ZR300』を発売しま
# ===============
# もはや格闘ドラマ? 松潤主演の「ラッキーセブン」は今後が楽しみな初回16.3%【話題】
# ---------------
#  「ラッキーセブン」の初回視聴率は16.3%で、月9枠の新たな方向性として期待されている。豪華なキャストと探偵モノというこれまでの月9とは異なる雰囲気が視聴者を楽しませた。恋愛だけではない幅広い層から
# ===============
# 気になる妊娠のこと「つわりって辛いですか?」
# ---------------
#  この記事では、妊娠初期に起こる吐き気などの症状「つわり」について、2人の女性の体験談が紹介されています。つわりの症状や程度には個人差があり、食べ物の匂いで気分が悪くなったり、逆に特定の食べ物を無性に
# ===============
# ウォンビンインタビュー「お互い寄り添うように助け合う愛もある」直筆サイン特別プレゼント
# ---------------
#  要約すると、この記事は、韓国映画「アジョシ」で主演男優賞を受賞したウォンビンの魅力と映画の見どころを紹介しています。
# ウォンビンは、「アジョシ」で拉致された少女を守るおじさん役を熱演し、今までの守ら
# ===============
# 「浅田真央が“4キロ激ヤセ”」と女性自身
# ---------------
#  与えられた文章の要約は以下の通りです。
#
#
# 浅田真央が四大陸選手権で銀メダルを獲得したが、それ以前に激やせしたことが話題になった。WEB版「女性自身」では激やせの原因を、食事会の中止による食生活の変
# ===============
# ジーコ、本田圭佑について「私がCSKAの監督だった時・・・」
# ---------------
#  この記事の要約は以下の通りです。
#
# 元日本代表監督のジーコが、日本と対戦するイラク代表監督としての複雑な心境や、イラク代表チームの自信を示しました。
#
# また、ジーコが日本代表チームを熟知していること
# ===============
# 『東京ガールズコレクション 2012』が1/7よりチケット先行発売
# ---------------
#  『第14回 東京ガールズコレクション 2012 SPRING/SUMMER』のチケット販売に関する要約です。
#
# チケットは、
#
# ・TGCメールマガジン会員先行販売(先着)が2012年1月7日から行わ
# ===============
# 【終了しました】食べるスキンケアで冬の枯れ肌を撃退!『美人食材を食べて1ヶ月できれいに! ビューティーレシピ』を5名様にプレゼント
# ---------------
#  この記事では、乾燥肌を体の内側から改善する効果が期待できるレシピが3つ紹介されています。
#
# 「アボカドと山いも&オクラのネバネバ丼」は、肌に潤いを与える山いもや、新陳代謝を高めるオクラ、皮膚の粘膜を
# ===============
# 独女的映画レビュー vol.13 『幸せの始まりは』
# ---------------
#  与えられた文章の内容を要約します。
#
# 映画「幸せの始まりは」のレビューです。主人公のリサはソフトボール選手で、マティとジョージという二人の男性の間で揺れ動きます。マティは鈍感で本能のままに生きるタイ
# ===============
# ′′20代の4割が童貞・処女′′にネット騒然
# ---------------
#  提示された記事の内容を要約します。
#
# 国立社会保障・人口問題研究所が発表した独身者調査によると、20〜24歳の男女のうち、4割以上が性経験がないと回答した。また、異性の交際相手がいない男性は61.4
# ===============
# デキる男はココが違う!超一流スパイが教える女を落とすテクニック
# ---------------
#  『Black&White/ブラック&ホワイト』という映画に登場する、CIAの凄腕トップエージェントであるFDRとタックが、同じ女性を好きになったことで、女性を落とすためのテクニックを駆使するという内
# ===============
# 【終了しました】幸せを運んでくれるかも? 南米パラグアイの銀細工ピアスを3名様にプレゼント
# ---------------
#  この記事では、南米パラグアイの銀細工ピアスのプレゼント企画を実施しています。フィリグリーと呼ばれる銀線細工の技術によって作られた、美しく繊細なアクセサリーです。プレゼントとして提供されるピアスは、３
# ===============
# 巨大都市ニューヨーク各所に出現した“どこでもドア”
# ---------------
#  この記事では、映画「アジャストメント」のブルーレイ＆DVD発売に伴い、ニューヨーク市内にドアノブを回すと目的地に行ける「運命のドア」が出現するという内容と、関連キャンペーンの告知が行われている。キャ
# ===============
# 元「モーニング娘。」高橋愛に熱愛スクープ。ファンから悲痛な叫び
# ---------------
#  明日発売の「FRIDAY」で、元モーニング娘。の高橋愛の熱愛スクープが掲載される。高橋愛の交際相手は、R-1出場経験のある37歳の芸人で、高橋を送迎しているという。具体的な相手の名前は出ていないが、
# ===============
# 六本木で「スター・ウォーズ」の祭典、ジョージ・ルーカスの娘も登場
# ---------------
#  要約:
#
#  「スター・ウォーズ DAY」が六本木で開催され、スター・ウォーズファンが集まりました。ジョージ・ルーカスの娘であるアマンダ・ルーカスが特別なビデオメッセージを紹介しました。また、ダース・
# ===============
# 2人の“エリカ様”が女優復帰会見でEXILEダンス披露
# ---------------
#  本文で述べられている内容を要約し、結果のみを出力します。
#
#
# 沢尻エリカが主演のドラマ「L et M  わたしがあなたを愛する理由、そのほかの物語」が、ケータイ専用放送局「BeeTV」で2月1日から
# ===============
# 【韓国ニュース】「眞露」が世界一も韓国ネットユーザーは意外な反応
# ---------------
#  記事の要約:
#
# 世界で最も売れた蒸留酒ブランドは韓国の焼酎「眞露」であることが、イギリスのメディア「デイリー・メール」によって報じられました。このニュースを韓国のネットユーザーは意外と受け止め、自国
# ===============
# 「平日休みの彼女とスケジュールがあわない」 - 辛口説教部屋 vol.31
# ---------------
#  この記事の内容を要約しました。
#
# 電気メーカーで営業として働く男性が、付き合い始めたホテルのベルガールの彼女と休みが合わず、デートが出来ずにすれ違いを感じてしまっているという相談に対して、チリちゃん
# ===============
# うっとうしい? うらやましい? 自分好きな人
# ---------------
#  この記事では、自分を好きな人、いわゆる自己肯定感の高い人について述べられています。自分好きな人は、恋愛においてはポジティブな思考回路を持ち、自信をもってアプローチすることができる一方で、仕事において
# ===============
# 【恋愛】恋の勝ち組になる!週間ランキング(20120326-20120401)
# ---------------
#  与えられた文章の要約は次の通りです。
#
# 恋愛をテーマとした記事週間ランキングの結果です。
#
# 第1位は、好きな人に振り向いてもらう方法について書かれた記事でした。
#
# 第2位、第5位には、男性の欲望や考
# ===============
# バイキングという食文化をどう思う?
# ---------------
#  この記事では、日本で最初にバイキング形式を導入したのは帝国ホテルであることが紹介されています。また、日本でのバイキング文化の広がりや、バイキングに関する人々の体験談を通じて、バイキングでのマナーや同
# ===============
# 【特集/JOURNEY】 刺激的で優しいアラブの国へ (7/8)
# ---------------
#  記事の内容を要約します。
#
# この記事では、ドバイを訪れる際のポイントと、優雅な滞在を楽しめるホテルを紹介しています。
#
# まず、ドバイでの滞在を満喫するためには、物価の安さにこだわらず、思いっきり楽し
# ===============
# 「MIHARAYASUHIRO」のショーをフォトレポート/東京コレクション・ウィーク
# ---------------
#  この記事では、東京コレクション・ウィークの一環として、MIHARAYASUHIROのファッションショー「ODYSSEY」について報告しています。
#
# 「ODYSSEY」は、都会から自然への一人の女性の
# ===============
# スパイからロック・スターへ転身? トムがミュージカル映画に初挑戦した予告映像が公開
# ---------------
#  『ロック・オブ・エイジズ』は、トム・クルーズが初挑戦するミュージカル映画で、ロック全盛期のスーパースター、ステイシー・ジャックを演じます。80年代を代表するロック・ナンバーが全編に使用され、トム・ク
# ===============
# 反日映画か? 『アジアの純真』日本公開に物議
# ---------------
#  与えられた記事を要約し、結果のみを出力します。
#
# 映画「アジアの純真」の初日舞台あいさつが物議をかもしました。この映画は日本での公開が危ぶまれていた作品で、ネット上では「反日映画」という意見が相次ぎ
# ===============
# グーグルプラスで衝撃! AKB前田敦子が顔面センターをついに持ちネタ化し好感度アップ【話題】
# ---------------
#  AKB48の前田敦子がGoogle+上で自分の顔のパーツがセンターに寄っていることをネタにした投稿をしたところ、ネットで好感度が上がった。以前から、前田はメンバーに顔文字で表現されていたが、今回自分
# ===============
# 「重たい女」にならないためには?
# ---------------
#  記事の要点は以下の通りです。
#
# 恋愛関係において、女性が「重い女」と思われないためには、相手に合わせて愛情表現を調節することが重要であると述べています。例えば、男性の仕事が忙しい場合、頻繁に会おうと
# ===============
# 歴代アメコミ・ヒーローを徹底比較! 原点ヒーロー“キャプテン・アメリカ”の実力を測る
# ---------------
#  キャプテン・アメリカ、スパイダーマン、バットマン、アイアンマンの特徴やヒーローになった経緯を比較した結果、以下のようになります。
#
# ・キャプテン・アメリカ
#
# 正体はスティーブ・ロジャース。平和を夢見
# ===============
# 「転職できる力」養成講座 その5 : 『東大卒でも赤字社員 中卒でも黒字社員』
# ---------------
#  「東大卒でも赤字社員 中卒でも黒字社員」の内容を要約すると、以下のようになります。
#
# ・会社で評価される社員の条件を会計的な視点から解説した本です。
#
# ・会社で戦力になるとは、会社の利益に貢献するこ
# ===============
# iPhoneの同期に要注意! 家族団らんが崩壊したとの報告あり【話題】
# ---------------
#  iPhoneの同期に関して注意が必要です。ある男性は、家族のパソコンでiPhoneを同期したことで、自分の趣味であるアダルトゲームの声優による萌えソングが家族のiPhoneに同期されてしまい、家族団
# ===============
# ただの女友達と好きな女の境界線
# ---------------
#  この記事は、「ただの女友達」と「好きな女」の境界線について、男性の意見をまとめたものです。主なポイントは以下の通りです。
#
# 1.「見た目」が好みかどうかが、友情と恋愛の境界線という男性もいます。
# 2
# ===============
# 20/47
#
# ['「FNSうたの夏まつり」でAKB48の生歌が「ひどかった」と話題に', '【週末映画まとめ読み】海外賞レースの行方は? 日本は仮面ライダーが怪物くんを抑える', '“草食男子”はギャルに不人気! 働く女子が好きなのは?', '全世界を席巻、最強“アベンジャーズ”現象が全米からヨーロッパへと拡大', 'タブレットの画面にヒビが!NTTドコモ「ケータイ補償 お届けサービス」を使ってみた【レポート】', '【Sports Watch】ザック・ジャパン、対韓国戦に「一人一人が判断を間違えていない」', '【Sports Watch】山本小鉄さん急逝も、死去直前も“豪傑ぶり”変わらず', 'くさったよめがあらわれた!vol.04「身内さえもオカズにするってダメですか!?」presented by ゆるっとcafe', 'ワイヤレスジャパン2012のニシケンブースにて「オーディオプロファイル対応の電話機型Bluetoothヘッドセット」を出展【レポート】', '【オトナ女子コミック部】最強“バカ枠”女子のお仕事マンガ『チャンネルはそのまま!』', '残暑見舞い挨拶の簡単挿入や書式の再利用 文書をカッコ良く効率的に作るWordの小技集【知っ得!虎の巻】', 'すっぴんにガッカリした男の本音/深夜に食べてもOKな夜食など−【ビューティー】週間ランキング', 'ヤラセ番組のつもりが本当の恐怖に! 動画サイトで再生回数2,100万回突破の超常現象映像', 'おはこんこん、アキバ大好き!祭りだよ【紺子にゅうす】', '乃木坂46の高山一実の過去ブログが流出し騒動に', '「何のための“予約”なんですか」孫社長に批判殺到', 'オトコのカラダ、どこに惹かれる?', '二度と見られない、故・森田芳光監督の貴重な演出シーン', '映画『TIME/タイム』、篠田麻里子のコメント入りCMが解禁「作品を邪魔しない声になっている」', 'スコア予想が的中した松木安太郎、「僕のいった扇原選手、清武選手がなんと活躍」', 'オフィスでツボ押しリラックス! 小型の温感マッサージャーはパナソニック「プチリフレ」【売れ筋チェック】', '独女的映画レビュー vol.10 『恋の商品価値』', '女探偵が語る ′′オトコとオンナの事情′′(後編)', '【Sports Watch】ロッテ西岡がモデルと結婚「ボクのワガママで誕生日に入籍する」', 'ソフトバンク、Androidスマートフォン「Vision 007HW」用ACアダプターのラベル不備で無償交換へ', '原子力基本法の改正に、韓国から「日本の核武装を阻止すべき」「我々も核武装だ」の声', '【DVDエンター!】美しき優等生が自慰行為、レズビアン・セックスに挑戦', 'この秋、ブルーレイディスクプレーヤーの新製品はソニーの独壇場!?', '「婚活疲労外来」医師に聞く「ああ、婚活疲れ」', '様々なデバイスでドラマや映画をシームレスに動画を視聴できるHulu【デジ通】', '韓国の竹島活動家、ヒトラーの言葉を引用し過激な主張を', 'ミラーレス一眼のミラーレスってなに?【いまさら聞けないデジカメ】']
# 32
# 「FNSうたの夏まつり」でAKB48の生歌が「ひどかった」と話題に
# ---------------
#  『FNSうたの夏まつり』に出演したAKB48の生歌が「ひどい」とネットで批判を受けた。
#
# AKB48グループは同番組で全84曲中、14曲に登場し、ネットでは「出過ぎ」との批判もあった。
# ===============
# 【週末映画まとめ読み】海外賞レースの行方は? 日本は仮面ライダーが怪物くんを抑える
# ---------------
#  以下の通り、週末映画まとめ読みの結果をお伝えします。
#
#
# １．仮面ライダーx仮面ライダー フォーゼ&オーズ MOVIE大戦 MEGA MAXが初登場1位
#
# ２．リアル・スティールが3位にランクイン
#
# ===============
# “草食男子”はギャルに不人気! 働く女子が好きなのは?
# ---------------
#  本文の要約:
#
# ギャル向けのリサーチ&ランキングサイト「GRP」が、会員のギャル約2万人にアンケートを取った結果、74.1%のギャルが草食男子を「嫌い」と回答し、草食男子の人気のなさが明らかになりま
# ===============
# 全世界を席巻、最強“アベンジャーズ”現象が全米からヨーロッパへと拡大
# ---------------
#  この記事の要点は以下の通りです。
#
# ・マーベル映画『アベンジャーズ』が全米で大ヒットし、ダークナイト・ライジングの記録を更新。日本でも限定前売り券が完売するなど人気の高さを示した。
# ・世界各国でワー
# ===============
# タブレットの画面にヒビが!NTTドコモ「ケータイ補償 お届けサービス」を使ってみた【レポート】
# ---------------
#  要約:
# この記事では、タブレットの画面が割れた場合に、NTTドコモの「ケータイ補償 お届けサービス」を利用した体験が述べられています。サービスの概要としては、月額料金を支払うことで、端末のトラブル時
# ===============
# 【Sports Watch】ザック・ジャパン、対韓国戦に「一人一人が判断を間違えていない」
# ---------------
#  サッカー日本代表チーム「ザック・ジャパン」が韓国代表と引き分け、強豪アルゼンチンとの初戦に続く健闘を見せた。解説者の風間八宏氏は、選手たちの集中力、素早い判断、そして攻守の連携を絶賛した。日本は年内
# ===============
# 【Sports Watch】山本小鉄さん急逝も、死去直前も“豪傑ぶり”変わらず
# ---------------
#  プロレスラーの山本小鉄さんが、低酸素脳症で急逝しました。引退後も選手育成や解説者、レフェリーとして愛された山本さんの死去直前の様子が、週刊アサヒ芸能に掲載されています。
#
# ターザン山本氏のコメントに
# ===============
# くさったよめがあらわれた!vol.04「身内さえもオカズにするってダメですか!?」presented by ゆるっとcafe
# ---------------
#  記事の内容を要約すると、以下のようになります。
#
# ライターの菜波さんの弟は、漫画やゲームの趣味が似ており、BLに対する理解がある人物であることが紹介されています。ある日、弟が友人から女装している少年
# ===============
# ワイヤレスジャパン2012のニシケンブースにて「オーディオプロファイル対応の電話機型Bluetoothヘッドセット」を出展【レポート】
# ---------------
#  この記事では、ワイヤレスジャパン2012でニシケンとiTechが共同で出展した、オーディオプロファイルに対応した電話機型のBluetoothヘッドセット「BluetoothPhone」について紹介さ
# ===============
# 【オトナ女子コミック部】最強“バカ枠”女子のお仕事マンガ『チャンネルはそのまま!』
# ---------------
#  佐々木倫子の最新作「チャンネルはそのまま!」は、北海道のローカルテレビ局を舞台にしたコメディ漫画である。主人公の雪丸花子は、天才的なドジで強運の持ち主の新入社員で、報道部に配属される。優秀だが容姿端
# ===============
# 残暑見舞い挨拶の簡単挿入や書式の再利用 文書をカッコ良く効率的に作るWordの小技集【知っ得!虎の巻】
# ---------------
#  要約します。
#
# この記事では、Wordで季節の挨拶状を効率的に作る方法や、表の書式設定や編集のテクニック、文書作成に役立つ機能などが紹介されています。具体的には以下のような内容が含まれます。
#
# ・W
# ===============
# すっぴんにガッカリした男の本音/深夜に食べてもOKな夜食など−【ビューティー】週間ランキング
# ---------------
#  先週の「ビューティ」カテゴリの人気記事ランキングの結果です。
#
# 1位:「すっぴんにガッカリした」男性の本音とは?
#
# 2位:女性特有の体の悩みについての回答集です。
#
# 3位:「ハイジニーナ脱毛」体験レ
# ===============
# ヤラセ番組のつもりが本当の恐怖に! 動画サイトで再生回数2,100万回突破の超常現象映像
# ---------------
#  要約すると、この記事では実際の超常現象を題材にしたリアリティ番組「グレイヴ・エンカウンターズ」の映画化作品が紹介されています。この作品は、廃墟となった精神病院を舞台に、心霊番組の撮影スタッフが超常現
# ===============
# おはこんこん、アキバ大好き!祭りだよ【紺子にゅうす】
# ---------------
#  ふぉっくす紺子のぬいぐるみが先週販売され、瞬く間に完売した。現在は、8/18にアキバ大好き!祭りのサンコーレアモノショップのブースで購入することができる。ぬいぐるみにはうちわとサイン入小冊子が付属す
# ===============
# 乃木坂46の高山一実の過去ブログが流出し騒動に
# ---------------
#  乃木坂46のメンバー高山一実と思われるブログの内容がネット掲示板で話題になりました。内容は、飲酒やアイドルを馬鹿にするような記述が含まれ、ファンからは批判が殺到しました。今後の処分については言及され
# ===============
# 「何のための“予約”なんですか」孫社長に批判殺到
# ---------------
#  この記事では、ソフトバンクの携帯電話およびスマートフォンの登録システムに障害が発生し、iPhone4Sの発売日に登録業務を午前11時以降停止したことが伝えられています。これにより、多くのユーザーが混
# ===============
# オトコのカラダ、どこに惹かれる?
# ---------------
#  この記事では、独女が魅力的だと感じる男性の身体の部位について紹介されています。具体的には以下のような部位が挙げられています。
#
# ・細くて長い指(特に手のひらがふっくらしている)
# ・キュッと引き締まっ
# ===============
# 二度と見られない、故・森田芳光監督の貴重な演出シーン
# ---------------
#  『僕達急行 A列車で行こう』の監督である森田芳光さんが急逝した後に遺作となった映画で、撮影現場での森田監督の貴重なシーンが収録されたメイキング映像が公開されました。
#
# 松山ケンイチさんは、「現場でい
# ===============
# 映画『TIME/タイム』、篠田麻里子のコメント入りCMが解禁「作品を邪魔しない声になっている」
# ---------------
#  記事の概要:
#
# AKB48の篠田麻里子が、映画「TIME/タイム」の日本語吹替版に出演することが決定し、コメント入りのCMが公開された。この映画は、成長が25歳で止まるという設定で、格差社会や時間の
# ===============
# スコア予想が的中した松木安太郎、「僕のいった扇原選手、清武選手がなんと活躍」
# ---------------
#  サッカー五輪最終予選でU-23日本代表がバーレーンを破り、ロンドン五輪出場を決めました。試合を解説していた松木安太郎氏は、事前の予想通り、扇原選手と清武選手の活躍を喜んだ一方、番組ゲストの宇治原史規
# ===============
# オフィスでツボ押しリラックス! 小型の温感マッサージャーはパナソニック「プチリフレ」【売れ筋チェック】
# ---------------
#  この記事は、パナソニック「プチリフレ」という小型の温感マッサージャーを紹介しています。この器具は、椅子の背もたれに置いて使用でき、背中と腰を優しくマッサージしたり、温めたりすることができます。エアー
# ===============
# 独女的映画レビュー vol.10 『恋の商品価値』
# ---------------
#  このテキストは、映画「恋の商品価値」についてのレビューです。レビューでは、主人公のミラベルがお金はないが愛を求めるアーティストとして、お金はあるが愛がない裕福なビジネスマンのレイと付き合うことで経験
# ===============
# 女探偵が語る ′′オトコとオンナの事情′′(後編)
# ---------------
#  与えられた文章の要約と結論は以下の通りです。
#
# 女性探偵が語る男女の事情に関する記事の後編です。探偵のもとに寄せられた依頼による意外な感動話として、結婚前に別れた女性の調査のエピソードが紹介されてい
# ===============
# 【Sports Watch】ロッテ西岡がモデルと結婚「ボクのワガママで誕生日に入籍する」
# ---------------
#  プロ野球選手の西岡剛が自身のブログでモデルの徳澤直子との結婚を発表しました。徳澤も自身のブログで結婚を報告しており、入籍日は西岡の誕生日である7月27日です。二人は過去にそれぞれ別の相手との交際が噂
# ===============
# ソフトバンク、Androidスマートフォン「Vision 007HW」用ACアダプターのラベル不備で無償交換へ
# ---------------
#  ソフトバンクモバイルは、Androidスマートフォン「Vision 007HW」のACアダプターのラベル不備を理由に、無償交換を実施すると発表しました。銘板ラベルに登録検査機関名称が表示されていない
# ===============
# 原子力基本法の改正に、韓国から「日本の核武装を阻止すべき」「我々も核武装だ」の声
# ---------------
#  日本の原子力基本法に安全保障の条項が追加されたことを受けて、韓国メディアは日本の核武装の可能性について懸念を示しています。韓国国民からも日本の核武装を警戒する声がネット上などで挙がっていますが、一方
# ===============
# 【DVDエンター!】美しき優等生が自慰行為、レズビアン・セックスに挑戦
# ---------------
#  『ブラック・スワン』の映画は、ニューヨーク・シティ・バレエ団に所属する主人公のニナ（ナタリー・ポートマン）が、バレエ劇『白鳥の湖』のプリマに選ばれ、純潔な白鳥と邪悪な黒鳥の二役を演じるプレッシャーに
# ===============
# この秋、ブルーレイディスクプレーヤーの新製品はソニーの独壇場!?
# ---------------
#  要約: 秋に発売されるブルーレイディスクプレーヤーについて、ソニーの「BDP−S480」「BDP−S380」の2機種が、ネット動画をテレビで楽しめ、スマートフォンがリモコンになる機能が特徴であり、ネ
# ===============
# 「婚活疲労外来」医師に聞く「ああ、婚活疲れ」
# ---------------
#  この記事では、婚活をする女性の約半数が過去1年間に何らかの婚活をしている一方で、思うような結果が出ず、ストレスを抱える人が増えている現状が述べられています。婚活疲労外来の小野博行医師によると、婚活疲
# ===============
# 様々なデバイスでドラマや映画をシームレスに動画を視聴できるHulu【デジ通】
# ---------------
#  この記事では、日本でのHuluのサービス開始について紹介されています。Huluは月額1,480円で、アメリカのテレビドラマやハリウッド映画を中心に、様々なデバイスでオンライン視聴できるサービスです。
# ===============
# 韓国の竹島活動家、ヒトラーの言葉を引用し過激な主張を
# ---------------
#  韓国のニュースサイト「韓国経済」によると、韓国が実効支配する竹島での活動家のホン・ソンリョン氏は、ヒトラーの言葉を用いて日本に対する強硬な主張を述べた。平和のために軍事力の準備が必要だと強調し、今年
# ===============
# ミラーレス一眼のミラーレスってなに?【いまさら聞けないデジカメ】
# ---------------
#  この記事では、ミラーレス一眼カメラと従来の一眼レフカメラとの違いについて説明しています。従来の一眼レフカメラには、レンズからの光をファインダーに送るためのミラーがありますが、ミラーレス一眼カメラには
# ===============
# 21/47
#
# ['雨・飴・なめなめ♪ カラフル飴でハッピーおやつタイム', '【週間売れ筋チェック】10月11日〜16日に一番売れたデジカメはキャノン「IXY 600F」', 'テレコムスクエア、日本で初めてミャンマー専用の携帯電話をレンタルするサービスを開始', 'iPhoneやケータイでカッコいいゴルファーを楽しむ【ゴルフ特集】', 'カスタマイズ性良し!使いやすい多機能Twitterクライアント「twitcle」【Androidアプリ】', '連載●After Effects 天国への階段 第8回【ビデオSALON】', 'キム・ヨナ、復帰宣言は“IOC選手委員になりたいという彼女の夢”!?', '増税・値上げに負けない!ノートPCでできるネット収入アップ化計画', 'サマンサタバサのイメージモデルになったAKB48指原莉乃が“公開処刑”の被害者に', '優しい上司は優柔不断!? 〜「判断」「指示する」ということ〜|実践!問題解決力テスト【第1問】', '秒速で′′泡だらけ′′! 女の欲望を叶える石けん「BLENDA BLACK DIAMOND」でもちもち美肌♪', 'フィリピンで日本人女性2人に性的暴行を加えた韓国人を逮捕 韓国ネットユーザーからは「日本は昔、同じことをやった」', '大島優子がここからどう破滅していくのか? 『闇金ウシジマくん』特報解禁', 'となりの会社のおやつ事情', 'au向けスマートフォン「HTC J ISW13HT」のおサイフケータイ機能が使えない不具合!初期化で改善', '楽天が電子書籍サービスを開始? 「Kobo」のサイトを新たに開設', '【韓国ニュース】 敗訴の影響か...サムスン「ギャラクシーS3」の販売価格が4分の1に', '簡単、清潔!タイガー「スチーム式加湿器 ATC-A300」は電気ポット感覚でお手入れ簡単【売れ筋チェック】', 'あなたのモテ期はいつやってきた?', 'Amazon.co.jp、電子書籍リーダー「Kindle」を近日発売と案内開始!お知らせメール登録も', '人気インストラクターに訊く ゴルフ〜はじめの一歩 <ラウンド&マナー編>', 'たった86gのフルハイビジョンカメラで峠を、ビーチを攻める!—サンワダイレクト『自転車車載カメラ(防水・フルHD)400−CAM011』【売れ筋チェック】', '【いちおう妖ヶ劇場】第11話:男は闘うために筋肉を鍛えマッスルの巻', '大御所ビートたけしに対しても空気を読まないオードリー・春日の発言に、伊集院光「衝撃受けた」', '中日落合監督、球団社長との握手を拒否', '不満だらけのランチタイム、ココを変えたい!', '被災者イジメ「津波で死ねばよかったのに」に非難殺到', '大切な彼へ上質な贈り物 手放せないあったか小物', '独身男女50名を無料ご招待! あの“青春白書”が楽しめる婚活パーティ開催 【プレゼント有】', '世界の映画祭で話題沸騰!インドネシアの壮絶バイオレンス・アクション『ザ・レイド』予告編が解禁', '魁!! ビデオ道場 2012年1月号【ビデオSALON】', '重量を当ててUltrabookをゲット! NEC LaVie Zの重さ当てクイズ【デジ通】']
# 32
# 雨・飴・なめなめ♪ カラフル飴でハッピーおやつタイム
# ---------------
#  この記事では、雨の日に気分を盛り上げるための、カラフルで可愛らしい飴について紹介しています。特に、キャンディー・アーティザンズ/キャンディー・ショータイムと岩井製菓の商品が取り上げられています。キャ
# ===============
# 【週間売れ筋チェック】10月11日〜16日に一番売れたデジカメはキャノン「IXY 600F」
# ---------------
#  Canonの「IXY 600F」が、10月11日から16日までの期間、最も売れたデジタルカメラであった。その特徴として、スリムなボディ（22.1mm）に光学8倍ズームレンズを搭載している。また、「マ
# ===============
# テレコムスクエア、日本で初めてミャンマー専用の携帯電話をレンタルするサービスを開始
# ---------------
#  テレコムスクエアは、日本で初めて、ミャンマー専用の携帯電話レンタルサービスを開始しました。サービス料金は、1日630円で、通話料金は発信1秒ごとに8.1円、着信1秒ごとに6.5円となります。補償サー
# ===============
# iPhoneやケータイでカッコいいゴルファーを楽しむ【ゴルフ特集】
# ---------------
#  与えられた文章の要約は以下の通りです。
#
#
# 最近のゴルフにおいて、道具からウェア、シューズなど様々な面でハイテク化が進んでおり、ゴルフナビ端末やデジタルカメラによるスイングチェックなどが注目されてい
# ===============
# カスタマイズ性良し!使いやすい多機能Twitterクライアント「twitcle」【Androidアプリ】
# ---------------
#  与えられた記事の要約は以下の通りです。
#
#
# Android用のTwitterクライアント「twitcle」は、使いやすく多機能であることが特徴です。
#
#
# 「twitcle」の主な機能や特徴には、次の
# ===============
# 連載●After Effects 天国への階段 第8回【ビデオSALON】
# ---------------
#  After Effectsのカラコレに関する記事の要約は以下になります。
#
# 手持ち撮影の動画をカラーグレーディングするためのテクニックが紹介されています。トラッキングの技術を併用することで、より正確
# ===============
# キム・ヨナ、復帰宣言は“IOC選手委員になりたいという彼女の夢”!?
# ---------------
#  バンクーバー冬季五輪・フィギュアスケート金メダリストのキム・ヨナは、ソチ五輪出場を最後に、現役を引退する意向を明かした。韓国内では、彼女の去就に関する憶測が飛んでいたが、引退表明のタイミングについて
# ===============
# 増税・値上げに負けない!ノートPCでできるネット収入アップ化計画
# ---------------
#  この記事の要点は以下の通りです。
#
# ・増税や値上げに対抗するために、ノートパソコンを利用したインターネット副業が注目されている。
# ・ノートパソコンの画面の小ささを解決する方法として「マルチモニター」
# ===============
# サマンサタバサのイメージモデルになったAKB48指原莉乃が“公開処刑”の被害者に
# ---------------
#  要約:
#  AKB48の指原莉乃がサマンサタバサのミューズに起用されたが、ネット上では起用を疑問視する声が多数上がった。指原の起用は、普段のキャラクターと異なることから、「公開処刑」という言葉も見られ
# ===============
# 優しい上司は優柔不断!? 〜「判断」「指示する」ということ〜|実践!問題解決力テスト【第1問】
# ---------------
#  記事の内容を要約します。
#
# 港君の上司である加藤課長は優しい性格で部下の意見をよく聞きますが、すぐに意見を変えてしまうので、課内が混乱しています。最近も月末の申込書の締切日を延長すると言ったり、元に
# ===============
# 秒速で′′泡だらけ′′! 女の欲望を叶える石けん「BLENDA BLACK DIAMOND」でもちもち美肌♪
# ---------------
#  この記事では、株式会社Preferred Elementsが開発したAIアシスタントであるPLaMoがおすすめする、「BLENDA BLACK DIAMOND」という洗顔石鹸について紹介しています。
# ===============
# フィリピンで日本人女性2人に性的暴行を加えた韓国人を逮捕 韓国ネットユーザーからは「日本は昔、同じことをやった」
# ---------------
#  フィリピンのセブ島で、韓国人男性2名が日本人女性2名に対して性的暴行を加えたとして逮捕された。被害に遭った日本人女性は語学留学中で、韓国人男性らと酒を飲んだ後に、モーテルで性的暴行を受けた。韓国人男
# ===============
# 大島優子がここからどう破滅していくのか? 『闇金ウシジマくん』特報解禁
# ---------------
#  「闇金ウシジマくん」の映画化が決定し、特報映像が公開された。AKB48の大島優子は母親の借金を肩代わりしたことで闇金業者のウシジマから取り立てを受け、堕ちていく役を演じる。原作に登場する肉蝮の「あの
# ===============
# となりの会社のおやつ事情
# ---------------
#  要約:
#
#  会社でのおやつの習慣は様々で、会社からおやつ代を支給される会社もあれば、課や部ごとに購入方法を決めている会社もあります。オフィスグリコのような置き菓子を利用している会社もあります。
#
#
# ===============
# au向けスマートフォン「HTC J ISW13HT」のおサイフケータイ機能が使えない不具合!初期化で改善
# ---------------
#  au向けスマートフォン「HTC J ISW13HT」の一部個体で、おサイフケータイ機能が使用できない不具合が発生しています。現在、原因は特定されておらず、auでは応急処置として、本体の初期化を案内し
# ===============
# 楽天が電子書籍サービスを開始? 「Kobo」のサイトを新たに開設
# ---------------
#  楽天株式会社は電子書籍サービス「Kobo」のサイトを新たに開設しました。メールアドレスを登録することで、電子書籍に関する最新情報をメールで受け取ることができるようになります。
# ===============
# 【韓国ニュース】 敗訴の影響か...サムスン「ギャラクシーS3」の販売価格が4分の1に
# ---------------
#  サムスンのスマートフォン「ギャラクシーS3」の卸売価格99万4400ウォンのLTEモデルが、韓国のスマートフォン売買サイトで加入費やU-SIM費用を免除したうえで、27万ウォンで販売されており、最新
# ===============
# 簡単、清潔!タイガー「スチーム式加湿器 ATC-A300」は電気ポット感覚でお手入れ簡単【売れ筋チェック】
# ---------------
#  この記事はタイガーのスチーム式加湿器 ATC-A300を紹介しています。この加湿器は電気ポットの技術を活かし、加湿器本体と水タンクが一体化しており、広口の蓋とフッ素コーティングで掃除がしやすい設計で
# ===============
# あなたのモテ期はいつやってきた?
# ---------------
#  記事の内容を要約すると、モテ期についての内容です。一般的に人生で3度あると言われているモテ期の定義や個人の体験談などが書かれています。記事に登場する「モテキ」という映画の主人公はほとんど恋愛経験がな
# ===============
# Amazon.co.jp、電子書籍リーダー「Kindle」を近日発売と案内開始!お知らせメール登録も
# ---------------
#  要約: Amazon.co.jpが電子書籍リーダー「Kindle」を近日中に日本で発売すると発表し、発売日やモデル、価格などの詳細は後日公開するとしています。これまで日本では海外向けのKindleを
# ===============
# 人気インストラクターに訊く ゴルフ〜はじめの一歩 <ラウンド&マナー編>
# ---------------
#  インタビュー最終回で、伊藤さんにラウンドとマナーについて聞いた結果、以下のように要約できます。
#
#
# ・ラウンドは積極的に行くべきだが、最初は経験者やインストラクターと一緒に行くのが良い。
#
# ・コース
# ===============
# たった86gのフルハイビジョンカメラで峠を、ビーチを攻める!—サンワダイレクト『自転車車載カメラ(防水・フルHD)400−CAM011』【売れ筋チェック】
# ---------------
#   この記事では、サンワダイレクトから発売された自転車車載カメラ「400-CAM011」を紹介しています。このカメラは、フルHDの高画質で最大2.5時間の録画が可能で、大きさはカメラ部分のみでW91×
# ===============
# 【いちおう妖ヶ劇場】第11話:男は闘うために筋肉を鍛えマッスルの巻
# ---------------
#  この物語では、元お嬢様の勅使河原栄華（てしがわらえいか）が貧乏生活をしながら、妖怪の住むアパートに住んでいます。彼女は映画好きのネコ仙人と出会い、一緒に生活しています。栄華は草食系の容姿のいい男性が
# ===============
# 大御所ビートたけしに対しても空気を読まないオードリー・春日の発言に、伊集院光「衝撃受けた」
# ---------------
#  要約:
# ビートたけしが出演する番組内のトークコーナーで、司会者のたけしがオードリーの芸をキュビズムになぞらえたが、春日俊彰がその意味が分からないと返し、場が凍りついた。この出来事に対し、伊集院光は衝
# ===============
# 中日落合監督、球団社長との握手を拒否
# ---------------
#  中日ドラゴンズの落合博満監督は、球団史上初のリーグ連覇を成し遂げたが、契約満了により今季限りの退任が決まっていた。落合監督は、自分を事実上解任した球団社長との握手を拒否したことが話題になった。一方で
# ===============
# 不満だらけのランチタイム、ココを変えたい!
# ---------------
#  記事の要約は以下の通りです。
#
# この記事は、節約傾向にある現代のオフィスワーカーのランチ事情を取り上げ、不満や希望を紹介しています。
# メインで登場するのは女性社員3名です。
#
# それぞれのランチの取り
# ===============
# 被災者イジメ「津波で死ねばよかったのに」に非難殺到
# ---------------
#  東日本大震災で転校した子供たちが、法務局が運営する「子どもの人権SOSミニレター」に深刻な悩みを寄せており、その数は1100通に上る。寄せられた手紙には、家族を亡くした悲しみや、学校でのいじめに関す
# ===============
# 大切な彼へ上質な贈り物 手放せないあったか小物
# ---------------
#  この記事では、ESTNATIONがおすすめする男性向けの暖か小物が紹介されています。ビジネスカジュアルなカラフルグローブ、高級感あるイントレ編みのグローブ、スマートにキマるダウンベスト、上質な肌触り
# ===============
# 独身男女50名を無料ご招待! あの“青春白書”が楽しめる婚活パーティ開催 【プレゼント有】
# ---------------
#  要約:
# 「新ビバリーヒルズ青春白書」のDVDリリースを記念して、結婚情報サイト「youbride」が、婚活パーティーを開催します。パーティーでは、ビバリーヒルズ青春白書にちなんだイベントが行われ、参
# ===============
# 世界の映画祭で話題沸騰!インドネシアの壮絶バイオレンス・アクション『ザ・レイド』予告編が解禁
# ---------------
#  この文章の要約は以下の通りです。
#
# インドネシア映画「ザ・レイド」は、麻薬王が支配する高層ビルを舞台にしたアクション映画です。SWATチームが強制捜査に乗り出し、激しい銃撃戦を繰り広げます。この映画
# ===============
# 魁!! ビデオ道場 2012年1月号【ビデオSALON】
# ---------------
#  「魁!! ビデオ道場 2012年1月号【ビデオSALON】」の要約は以下の通りです。
#
# 読者の投稿コーナー「ビデオパーク」が「魁!! ビデオ道場」にリニューアルしました。毎月、読者からの投稿作品の中
# ===============
# 重量を当ててUltrabookをゲット! NEC LaVie Zの重さ当てクイズ【デジ通】
# ---------------
#  この記事ではNECの新型UltrabookであるLaVie Zの重量当てクイズについて書かれています。記事によると、このLaVie Zは新素材であるマグネシウムリチウム合金を採用しており、これにより
# ===============
# 22/47
#
# ['次世代ジェットコースター・ショッカー・ミステリー! 『スクリーム4』がブルーレイ&DVDになって登場', '江原啓之「オセロ中島は被害者でない」がネットで話題に', '海外向けSIMフリーモデル「HTC One V T320e」を使ってみよう!多少もっさり?ベンチマークを計ってみた【レビュー】', '“アベンジャーズ現象”日本上陸、早朝の六本木ヒルズに長蛇の列が出現', 'ケーキをデコレーションしてスウィートなプレゼントをGETしよう!', '年収1000万円のビジネスマンに聞いた「共同購入型クーポンサイトについて」 - 年収1000万円研究所 vol.11', 'NTTドコモ、GALAXY SII SC-02CのAndroid 4.0 ICSへのOSバージョンアップを再開!Android 4.0適用後の不具合も解消[Galaxy_Report]', 'パナソニック、ミラーレスタイプのデジタル一眼カメラ「DMC−G5」を発売【売れ筋チェック】', '歯の間が驚くほど清潔に!フィリップスから電動デンタルフロスが新発売【売れ筋チェック】', '悲しいかな、おばさんファッションへと移行していく理由', 'エコタクドットコム、iPhoneをはじめとするスマートフォンの修理やグッズを扱う「SMART Echika 池袋店」をオープン!', '恋に効くコラムLesson2 恋愛を長く休みがち...。新しい恋に出会うには?', '北朝鮮観客席の様子を伝えたアナウンサー「統率がとれていました」', 'これで今日からExcelの達人!ビジネスに必須のExcel基本ワザ【知っ得!虎の巻】', 'サービス開始3周年記念!UQコミュニケーションズ、WiMAX対応モバイルWi-Fiルーター「AtermWM3600R」のブルーガチャムク特別限定モデルを7月6日に発売', 'あの頃に戻りたい...。戻りたいのはいつ?', '話題の最新スマホの予約日が決定!ドコモ、MEDIAS X N-07Dを発売へ', '「演歌の始祖は韓国人」が話題に', '【Sports Watch】まだまだいるぞ! かわいい次世代なでしこ', 'ダイヤモンドの輝きを手軽にシミュレートできる「EXELCO DIAMOND」【Androidアプリ】', 'エイリアンの生態を徹底解剖!世界一の映像チームがつくる緻密な造形美術', '【韓国ニュース】「モテなかったから僧侶になった」 韓国僧侶の発言が話題呼ぶ', 'ZTE、Intel製「Atom」搭載のAndroidスマートフォン「ZTE Grand X IN」を発表!欧州で9月に発売', '<コラム>名手が愛したパター【ゴルフ特集】', '【Sports Watch】プロ野球でドーピングが発覚? ダルビッシュは「セ・リーグって話」', '【最近のオススメ「Androidアプリ」特集:2012年5月28日〜6月3日編】', '嫉妬で彼を束縛していませんか?', '第24回東京国際映画祭作品ガイド<ワールドシネマ部門>', '名物七大鍋でお腹も心も大満足 【プレゼント有り】', '国内専用モデル「HTC J」投入で本気を出した——「HTC One」に賭けるHTCのスマホ戦略に迫る【山根康宏の“世界のモバイル”】', 'ANREALAGE(アンリアレイジ)|“東コレ”Bestブランド探訪!', '女が選ぶ「キレイに年齢を重ねている女」']
# 32
# 次世代ジェットコースター・ショッカー・ミステリー! 『スクリーム4』がブルーレイ&DVDになって登場
# ---------------
#  『スクリーム4：ネクスト・ジェネレーション』が、ブルーレイ＆DVDとなって3月2日に発売されます。この作品は、『スクリーム』シリーズの最新作で、11年ぶりの新作として2011年に公開されました。物語
# ===============
# 江原啓之「オセロ中島は被害者でない」がネットで話題に
# ---------------
#  スピリチュアルカウンセラーの江原啓之は、オセロ中島の騒動について「被害者ではない」と発言し、ネット上で賛否両論が巻き起こっている。江原は中島の状況をマインドコントロールではなく共依存と指摘した上で、
# ===============
# 海外向けSIMフリーモデル「HTC One V T320e」を使ってみよう!多少もっさり?ベンチマークを計ってみた【レビュー】
# ---------------
#  この記事では、「HTC One V T320e」という海外向けSIMフリースマートフォンのベンチマークを計測した結果が述べられています。使用されたベンチマークアプリは「Quadrant Standa
# ===============
# “アベンジャーズ現象”日本上陸、早朝の六本木ヒルズに長蛇の列が出現
# ---------------
#  この記事の結果として、以下のことが起こっています。
#
#
# ・日本版の映画「アベンジャーズ」の特別前売り券が数量限定で発売された。
#
# ・早朝から長蛇の列ができ、ファン層も幅広いことがうかがえる。
#
# ・特
# ===============
# ケーキをデコレーションしてスウィートなプレゼントをGETしよう!
# ---------------
#  この記事は、auとHangameが共同で行っている「ドキドキ★スマホキャンペーン」の一環である「スウィートキャンペーン」の告知と説明です。「スウィートキャンペーン」は、Android用アプリ「ハッピ
# ===============
# 年収1000万円のビジネスマンに聞いた「共同購入型クーポンサイトについて」 - 年収1000万円研究所 vol.11
# ---------------
#  要約した結果は以下の通りです。
#
# ・ビズリーチ年収1000万円研究所によるアンケート調査の結果、年収1000万円のビジネスマンの約半数が共同購入型クーポンサイトを認知している一方で、利用経験がある人
# ===============
# NTTドコモ、GALAXY SII SC-02CのAndroid 4.0 ICSへのOSバージョンアップを再開!Android 4.0適用後の不具合も解消[Galaxy_Report]
# ---------------
#  この記事では、NTTドコモがGALAXY SII SC-02CのAndroid 4.0 ICSへのOSバージョンアップを再開したことを伝えています。バージョンアップの一時停止理由であった不具合が解消
# ===============
# パナソニック、ミラーレスタイプのデジタル一眼カメラ「DMC−G5」を発売【売れ筋チェック】
# ---------------
#  PLaMoが要約した本文の内容は、以下の通りです。
#
# パナソニックは、9月13日にミラーレスデジタル一眼カメラ「DMC-G5」を発売します。このカメラは、小型・軽量ボディに内蔵ファインダーを搭載し、
# ===============
# 歯の間が驚くほど清潔に!フィリップスから電動デンタルフロスが新発売【売れ筋チェック】
# ---------------
#  内容要約: フィリップスから新発売された電動デンタルフロス「フィリップス ソニッケアー エアーフロス」は、独自技術であるマイクロバーストテクノロジーにより、加圧された空気と水を噴射して歯間の歯垢をや
# ===============
# 悲しいかな、おばさんファッションへと移行していく理由
# ---------------
#  与えられた文章を要約します。
#
# アラフォー世代の女性たちが自分に似合う服が分からなくなり、おばさんファッションへと移行していく理由を考察した文章です。
#
# 洋服選びに悩む女性たちの例として、以下のよう
# ===============
# エコタクドットコム、iPhoneをはじめとするスマートフォンの修理やグッズを扱う「SMART Echika 池袋店」をオープン!
# ---------------
#   エコタクドットコムは4月25日、池袋駅構内の商業施設「Echika 池袋」内に「SMART Echika 池袋店」をオープンしました。同店は、iPhoneやAndroidスマートフォンの修理やアク
# ===============
# 恋に効くコラムLesson2 恋愛を長く休みがち...。新しい恋に出会うには?
# ---------------
#  与えられた文章の要約は以下の通りです。
#
# 恋愛の達人・石田純一さんが、なかなか恋愛ができないと悩む女性にアドバイスを送ります。恋愛をお休みしている期間は次の恋愛や愛に進むための準備期間として捉え、一
# ===============
# 北朝鮮観客席の様子を伝えたアナウンサー「統率がとれていました」
# ---------------
#  与えられた文章の内容を要約し、結果のみを出力します。
#
# 北朝鮮スタジアムに集まった北朝鮮サポーターは5万人。試合前から恐ろしいまでの一体感を見せ、日本代表を応援する日本サポーターを圧倒しました。
#
#
# ===============
# これで今日からExcelの達人!ビジネスに必須のExcel基本ワザ【知っ得!虎の巻】
# ---------------
#  与えられた文章を要約しました。
#
# 「知っ得!虎の巻」というサイトでExcelの便利な技が紹介されています。例えば、オートフィル機能を使って、マウス操作で簡単に連続したデータを入力する方法があります。
# ===============
# サービス開始3周年記念!UQコミュニケーションズ、WiMAX対応モバイルWi-Fiルーター「AtermWM3600R」のブルーガチャムク特別限定モデルを7月6日に発売
# ---------------
#  内容の要約と結果:
#
# UQコミュニケーションズは、WiMAX対応モバイルWi-Fiルーター「AtermWM3600R」の特別限定モデル、ブルーガチャムク「PA-WM3600R(AT)H」を、7月6日
# ===============
# あの頃に戻りたい...。戻りたいのはいつ?
# ---------------
#  この記事では、様々な年齢の女性に「あの頃に戻りたい」というテーマでインタビューした内容をまとめています。「あの頃」は人によって異なり、大学生や社会人、浪人時代などを指しています。記事に登場する女性た
# ===============
# 話題の最新スマホの予約日が決定!ドコモ、MEDIAS X N-07Dを発売へ
# ---------------
#  要約:ドコモは「docomo with series MEDIAS X N-07D」の事前予約を7月6日より開始し、発売日は7月13日を予定していますが、正式な販売開始日は別途発表されます。予約は「
# ===============
# 「演歌の始祖は韓国人」が話題に
# ---------------
#  サーチナの報道によると、韓国のテレビ番組に出演した日本の演歌関係者が、演歌の起源は韓国にあると発言したことが話題になっています。この発言が韓国のネット掲示板で支持されているという内容です。これに対し
# ===============
# 【Sports Watch】まだまだいるぞ! かわいい次世代なでしこ
# ---------------
#  この記事では、女子サッカーW杯で優勝したなでしこジャパンの人気が続いていることを伝えている。特に、川澄奈穂美、澤穂希などの選手がメディア出演し、さらなる人気を集めている。また、なでしこジャパンの妹分
# ===============
# ダイヤモンドの輝きを手軽にシミュレートできる「EXELCO DIAMOND」【Androidアプリ】
# ---------------
#  この記事では、「EXELCO DIAMOND」というAndroidアプリを紹介しています。このアプリでは、ユーザーがダイヤモンドのカラット数、デザインを選択し、バーチャルに指輪を試着することができま
# ===============
# エイリアンの生態を徹底解剖!世界一の映像チームがつくる緻密な造形美術
# ---------------
#  提供された文章は、映画「スカイライン-征服-」の特集記事の冒頭部分のようです。この映画は、地球外生命体による人類征服を描いたSF作品で、緻密な映像美で描かれるエイリアンの生態や世界観が見どころのよう
# ===============
# 【韓国ニュース】「モテなかったから僧侶になった」 韓国僧侶の発言が話題呼ぶ
# ---------------
#  この記事は、韓国の僧侶であるヒョボン氏が自身のFacebook上で明かした、「異性にモテなかったから僧侶になった」という発言が韓国のインターネット上で話題になっていることを伝えています。
#
# ヒョボン
# ===============
# ZTE、Intel製「Atom」搭載のAndroidスマートフォン「ZTE Grand X IN」を発表!欧州で9月に発売
# ---------------
#  記事では、ZTEがIntel Atomプロセッサ搭載のAndroidスマートフォン「ZTE Grand X IN」を発表したことを伝えています。このスマートフォンは、欧州で2012年9月に発売される
# ===============
# <コラム>名手が愛したパター【ゴルフ特集】
# ---------------
#  与えられた文章の要約は、以下の通りです。
#
# 歴代のパッティング名手は、名器と呼ばれる特定のパターを愛用し続ける傾向があります。名手のパッティングを支えてきた有名なパターとして、ベン・クレンショーの「
# ===============
# 【Sports Watch】プロ野球でドーピングが発覚? ダルビッシュは「セ・リーグって話」
# ---------------
#  この記事では、日本のプロ野球界でドーピングが発覚したという内容について、速報的に伝えています。ドーピングがあったとされる球団は、当初は明らかにされていませんでしたが、北海道日本ハムファイターズのダル
# ===============
# 【最近のオススメ「Androidアプリ」特集:2012年5月28日〜6月3日編】
# ---------------
#  与えられたテキストから以下のように要約しました。
#
#
# ここ1週間ほどで取り上げたAndroidアプリの紹介記事をまとめました。Google日本語入力のバージョンアップ、ドコモのセキュリティアプリの機
# ===============
# 嫉妬で彼を束縛していませんか?
# ---------------
#  記事の概要としては、嫉妬に苦しむ女性二人の例を挙げながら、恋愛関係において嫉妬がもたらす悪影響と、適度な距離感を持つことの重要性を述べています。
#
# 要約すると以下のようになります。
#
# 1. カップル
# ===============
# 第24回東京国際映画祭作品ガイド<ワールドシネマ部門>
# ---------------
#  第24回東京国際映画祭のワールドシネマ部門で上映される作品として、以下の作品が紹介されています。
#
#
# ・『アナザー・ハッピー・デイ』 - 結婚式に集まった家族の複雑な人間関係を描いた作品。サンダンス
# ===============
# 名物七大鍋でお腹も心も大満足 【プレゼント有り】
# ---------------
#  この記事では、浜松町駅近くの鍋料理専門店「海ぶん鍋ぶん」の名物のオリジナル鍋を紹介しています。「漁師鍋」「白湯鍋」「ゆず豆乳鍋」「ちりとり鍋」「ゴマ坦々麺」「赤カレー鍋」「白ちゃんこ鍋」の7種類の鍋
# ===============
# 国内専用モデル「HTC J」投入で本気を出した——「HTC One」に賭けるHTCのスマホ戦略に迫る【山根康宏の“世界のモバイル”】
# ---------------
#  与えられた文章の要点をまとめました。
#
#
# 「HTC J ISW13HT」は、日本市場での販売が好調であり、従来のHTC製品の印象を変えつつある。海外では、HTCが「HTC One」ブランドを推してお
# ===============
# ANREALAGE(アンリアレイジ)|“東コレ”Bestブランド探訪!
# ---------------
#  この記事では、日本のファッションブランドANREALAGEが、2012年春夏コレクションで発表した作品について書かれています。テーマは「SHELL」で、視覚や触覚に訴えかける様々な衣服が展示されまし
# ===============
# 女が選ぶ「キレイに年齢を重ねている女」
# ---------------
#  与えられた文章の要約は以下の通りです。
#
# 「オバサン」ではなく「大人の女」になるための理想の歳の取り方についてのアンケート調査の結果です。
#
# 男性が思う「キレイに年齢を重ねている女性芸能人」は
#
# ・
# ===============
# 23/47
#
# ['スマートフォンで操れる! パナソニック、Wi−Fi搭載スリムズームのデジカメ「LUMIX DMC−SZ5」を発売【売れ筋チェック】', 'すげー、資料にはまだ髪がある!孫社長「記念すべき日になりました」', '世界でひとつ!自分だけの洗練“革”アイテムをオーダーで', '新ビジネスやワークスタイルを紹介!企業を商品で繋ぐ「zigBiz」で新コンテンツを配信', 'お散歩で開運! 恋愛運UPのおすすめスポット', '事故防止に耳掛けタイプが注目! 「居眠り感知器」の売り上げが急増中【売れ筋チェック】', '“食”をテーマにしたまったく新しいフェスが誕生!', '難易度の高い舌を噛みそうなオーダーもこのアプリさえあれば大丈夫!スタバ通になれる「スタバコール」【iPhoneアプリ】', 'ファンすら怒る秋元康の「えげつない」商売戦略', '非公式アプリでも結構イケる! UbuntuでもEvernoteが使える【デジ通】', '冷える日本列島! 寒い年末年始をぬくぬく過ごせる便利グッズ', '睡眠と生活改善でやせる!? アラフォー向けの健全ダイエット', '希少な焼酎とホルモンをワンコインで堪能  【プレゼント有】', 'IT関連企業 取締役「塩ごはんさえご馳走だった」 - 年収1000万円プレイヤー図鑑 vol.1', '速い! 進化したオートフォーカスは0.1秒!! リコーが「CX6」を発売【売れ筋チェック】', '今度の金環食を見逃さない! 来る5月21日の金環食を楽しむアプリ【iPhoneでチャンスを掴め】', '【Sports Watch】プロレスのオールスター戦開催も、猪木は呼ばれず激怒', '【いちおう妖ヶ劇場】第6話:バレンタインチョコなんて、ちょこっとも欲しくないの巻', '【Sports Watch】俊足すぎるFW=U-22日本代表・永井の“スピード伝説”とは?', '3D映像にハマる!ソニーのゴーグル型ディスプレイHMZ-T1【売れ筋チェック】', 'NHK「ひるブラ」で放送事故が発生', '古来より伝わる「植物療法」で肌質改善宣言!', 'ついに萌えキャラに手を出し始めた野球界', 'あなただけのオリジナルダンス作成! Twitter/Facebook連動コンテンツ「重低音BROTHERS meets EXTRA BASS 」', '【韓国ニュース】月一で来日し、日本全国でデモする韓国の農民とは', '正直な貯金額、人に言えますか? Presented by ゆるっとcafe', '進化し続ける「レンジ専用食品」 電子レンジを“相棒”にする「レンジェンヌ」とは!?', 'テレビも電子書籍もインターネットも! お風呂を楽しむなら 「ビエラ・ワンセグ」SV−ME1000【売れ筋チェック】', '韓国人の彼氏が徴兵されることについて', '「王室は廃止すべき?」 英国のネット掲示板で大論争', '1位は友達! あなたは1週間でいちばん誰に多くメールする?【話題】', '2年間で20万円超のスマホ料金!? 音声専用契約からの変更では何と6倍に【デジ通】']
# 32
# スマートフォンで操れる! パナソニック、Wi−Fi搭載スリムズームのデジカメ「LUMIX DMC−SZ5」を発売【売れ筋チェック】
# ---------------
#  パナソニックが光学10倍ズームレンズ(超解像iAズーム20倍)とWi-Fiを搭載したデジタルカメラ「LUMIX DMC-SZ5」を8月23日に発売します。現在、スマホの内蔵カメラの高性能化やスマホの
# ===============
# すげー、資料にはまだ髪がある!孫社長「記念すべき日になりました」
# ---------------
#  提示された記事の要約は以下の通りです。
#
#  ソフトバンクグループの孫正義代表は、自身のTwitter上でプラチナバンド認可を受け、記者会見を開いたことを明らかにしました。ユーザーからは、孫氏の新しい
# ===============
# 世界でひとつ!自分だけの洗練“革”アイテムをオーダーで
# ---------------
#  この記事では、横須賀市にある革作家シダータさんの革製品のオーダーメイドアトリエを紹介しています。シダータさんの作品の魅力は質の高さにあり、個人のオーダーに応じて手縫いのバッグを作ることもあります。個
# ===============
# 新ビジネスやワークスタイルを紹介!企業を商品で繋ぐ「zigBiz」で新コンテンツを配信
# ---------------
#  この記事では、企業間取引に特化したレビューサイト「zigBiz」の紹介と、会員企業による新たなビジネスやワークスタイルの紹介、および企業向け製品のレビューキャンペーンについて述べられています。「zi
# ===============
# お散歩で開運! 恋愛運UPのおすすめスポット
# ---------------
#  与えられた文章の要約は以下の通りです。
#
# 新宿アイランドの恋弁天、銀座の天使の像、三愛ドリームセンターのコイコリンの像はどれも恋愛運が上がると言われている有名スポットです。恋弁天は出雲大社のお墨付き
# ===============
# 事故防止に耳掛けタイプが注目! 「居眠り感知器」の売り上げが急増中【売れ筋チェック】
# ---------------
#  車の事故が相次いで報道され、関心が高まっている昨今、耳掛けタイプの居眠り感知器、「NAP VIEEB PLUS II」の売り上げが急増しています。
# この商品は海外で先行して人気を集めており、日本国内
# ===============
# “食”をテーマにしたまったく新しいフェスが誕生!
# ---------------
#  食をテーマにした新しい巨大飲食フェスティバル「まんパク」が2011年10月に東京臨海広域防災公園で開催されます。音楽フェスの開催で定評のあるロッキング・オンが企画制作を行うこのイベントでは、ラーメン
# ===============
# 難易度の高い舌を噛みそうなオーダーもこのアプリさえあれば大丈夫!スタバ通になれる「スタバコール」【iPhoneアプリ】
# ---------------
#  この記事では、iPhone向けのアプリ「スタバコール」を紹介しています。このアプリは、スターバックスの複雑な注文をサポートするために開発されました。スターバックスのドリンクをカスタマイズする際に、サ
# ===============
# ファンすら怒る秋元康の「えげつない」商売戦略
# ---------------
#  郵便局株式会社は、AKB48のチーム別の切手セットを販売すると発表しました。各チームのメンバーの顔が印刷された切手とグッズのセットで、価格は5,700円ですが、実際の切手は1,000円分のみで、残り
# ===============
# 非公式アプリでも結構イケる! UbuntuでもEvernoteが使える【デジ通】
# ---------------
#  「非公式アプリでも結構イケる! UbuntuでもEvernoteが使える」という記事の要約です。
#
#
# 　Ubuntuには標準で多くのアプリが付属していますが、中には足りないものもあります。例えば、人
# ===============
# 冷える日本列島! 寒い年末年始をぬくぬく過ごせる便利グッズ
# ---------------
#  この記事では、寒い冬におすすめの便利グッズを3点紹介しています。
#
# 1つ目は「USBあったかオニギリウォーマー」で、電子レンジがなくても温かいおにぎりが食べられます。
#
# 2つ目は「USBマウスウォー
# ===============
# 睡眠と生活改善でやせる!? アラフォー向けの健全ダイエット
# ---------------
#  与えられた記事の内容を要約し、結果を出力します。
#
#
# 「睡眠と生活改善でやせる!? アラフォー向けの健全ダイエット」という記事では、睡眠時間と体重減少の関係について述べられています。
#
#
# 筆者は、睡
# ===============
# 希少な焼酎とホルモンをワンコインで堪能  【プレゼント有】
# ---------------
#  この文章は恵比寿にあるホルモン専門店についてのもので、そのお店の特徴は以下の通りです。
#
# ・恵比寿駅から徒歩約3分の場所にある、バーのような外観のお店で、居心地の良いカウンター席があり、一人で立ち寄
# ===============
# IT関連企業 取締役「塩ごはんさえご馳走だった」 - 年収1000万円プレイヤー図鑑 vol.1
# ---------------
#  この記事では、大手通信キャリアを経て特許エンジニアとなり、現在はIT企業の取締役を務める緒方氏の経歴や考え方について述べられています。緒方氏は、もともと弁理士を目指していましたが、まずは民間企業の経
# ===============
# 速い! 進化したオートフォーカスは0.1秒!! リコーが「CX6」を発売【売れ筋チェック】
# ---------------
#  リコーが新オートフォーカスシステムを搭載したデジタルカメラ「CX6」を発売します。新システムにより、AF合焦時間は最短0.1秒となり、高性能な画像を手軽に撮影することができます。「CX6」の特徴は以
# ===============
# ...
# 東京モーターサイクルショー2010/コンパニオン写真集
# ---------------
#  東京モーターサイクルショー2010では、国内外のオートバイメーカー約130社の展示ブースが出展されました。このイベントでは、日本での販売を前に、米国最古のオートバイメーカーであるインディアンの車両が
# ===============
# 職場内の整理・整頓すらできない大阪府職員に「小学校から出直せ」
# ---------------
#  記事の内容を要約すると、大阪府の松井一郎知事が府職員に対し、業務改善として職場の整理・整頓を勤務時間内に行ったことに対して注文をつけました。
# 松井知事は「整理・整頓は勤務時間外に」と発言し、時間外に
# ===============
# 好調のアプリ取り放題プラン「auスマートパス」に落とし穴! 解約したらアプリはすべて消去されてしまう【話題】
# ---------------
#  auスマートパスの落とし穴として、解約時にほとんどのアプリが消去されてしまうことがあげられます。そのため、気軽に解約できない点が注意点です。
# ===============
# 一夜限り!広末涼子ら出演の懐かしいドコモCMがオンエア
# ---------------
#  NTTドコモは、20周年のスペシャルドラマ「夢の扉特別編 『20年後の君へ』」を7月1日夜9時からTBS系で放送します。ドラマ内では、懐かしのNTTドコモのCMがオンエアされます。「葉月、ブルった？
# ===============
# クローゼットを変えれば自分が変わる!?
# ---------------
#  この記事の要約は以下の通りです。
#
# クローゼットの整理により、ファッションや運気に影響が出ることを述べています。不要な服を溜め込んだクローゼットは、「もったいない」という気持ちが働いてしまうが、その
# ===============
# 死ぬまで戦え! 『スターシップ・トゥルーパーズ』昆虫と人類の壮絶な戦いが再び
# ---------------
#  ロバート・A・ハインラインの小説「宇宙の戦士」を原作にした人気SFシリーズの最新作、「スターシップ・トゥルーパーズ インベイジョン」の公開日が7月21日に決まり、特報映像が解禁された。日本が世界に向
# ===============
# 【Sports Watch】原発事故で危機に立たされた女子アスリート
# ---------------
#  東京電力女子サッカー部マリーゼは、東日本大震災による福島原発の事故により、チームの存続が危ぶまれています。選手たちは東京電力の社員であり、事故後は自宅待機となっており、活動再開の目途は立っていません
# ===============
# NTTドコモ、コンパクトなXi対応モバイルWi-Fiルーター「L-04D」を発表
# ---------------
#  NTTドコモは夏モデルとして、LGエレクトロニクス製のモバイルWi-Fiルーター「L-04D」を発表しました。このルーターはXi（クロッシィ）に対応しており、対応エリアでは下り最大75Mbps、上り
# ===============
# 【記事連動】音の編集講座「音量の合わせ方」【ビデオSALON】
# ---------------
#  要約すると、この記事の内容はビデオ編集講座で、ビデオサロン12月号の付録として、ビデオ編集における音量の合わせ方に焦点を当てています。関連記事として、雑誌やイベントのレポート、製品レビューなどが紹介
# ===============
# 【終了しました】身体を温めてナチュラル・ビューティを目指そう。温熱サロン無料体験を2名様にプレゼント
# ---------------
#  この記事では、体温の重要性や、低体温による健康と美容への影響、そして身体を温める温熱セラピーを紹介しています。温熱ケアサロンMARでは、ヒートショックプロテインを生成するための熱刺激を与える温熱セラ
# ===============
# 夢を見ると綺麗になれる——、女子力アップに“宝くじ”のワケ
# ---------------
#  記事では、宝くじがもたらすポジティブな効果について述べられています。宝くじの高額当選を夢見ることで、女性の美しさに関わる脳内ホルモン(ドーパミン、セロトニン)が分泌され、ストレス解消や自律神経・ホル
# ===============
# 働く女は上を目指す! 3人に1人は「2010年中に転職したい」
# ---------------
#  トレンダーズ株式会社が行なった、25〜35 歳の女性(有職者)500 名に対する「転職」に関する意識調査によると、現在の仕事に不満を持つ女性は9割にも上り、3人に1人は今年中に転職したいと考えている
# ===============
# 新生活に格闘技ライフを——、人気の柔術ジムに行ってきました【新生活特集】
# ---------------
#  この記事では、柔術という格闘技についてと、東京の秋葉原と恵比寿に新しくオープンした柔術ジムについての内容で、以下のように要約できます。
#
#
# 「柔術」とは寝技を主体とした格闘技で、様々な目的を持った老
# ===============
# 44/47
#
# ['独女の疑問......結婚後のマイホーム購入は当たり前?', '人生観が変わる!? 一度は行ってみたい世界のあの場所!', 'iTunes史上最高のダウンロード数を記録した『ダークナイト ライジング』の予告映像を公開', '映画『荒川アンダー ザ ブリッジ』より“俺のスターアルバム”発売決定', '3D全盛の時代に、白黒のサイレント映画『アーティスト』が評価される理由', '【元気東北・福島編】雪国を南国にした福島人の底力', '女子力アップの簡単“キメ技”術指南 vol.2', '謎のモザイク美女の正体はAKB48の篠田麻里子、声優挑戦は成功するか', '脳を刺激する“極上のミステリー”が誕生!攻防戦を繰り広げる予告映像が公開', '日ハム・大嶋匠、連日の活躍にも「少年野球以来なので、野球をするのは」', '台湾でHappy開運の旅 絶品豆乳と極楽マッサージでリフレッシュ', '専用のPlayキーを持つ防水ミュージックプレイヤー スマートフォン「AQUOS PHONE st SH-07D」【レビュー】', 'ネットで悪口を書かれたらどうすればいい?', '【オトナ女子のリアルな悩み】転職を繰り返してしまう40代女子の本音', '待望のEOS 5D Mark III、動画の進化のポイントは?【ビデオSALON】', 'ブランド牛のニューフェイス、“恵比寿牛”ってどんなお肉?', '落合元監督、“内川へのクレーム”に言及 「もし専門家に言わせたら・・・」', '無職ランナーをオリンピックへ! プレアカ1か月分でスポンサーになれる', '【スナップレポート】東京ガールズコレクション 2011 藤井リナ編', 'ご飯炊けまくりマシタ! 仲良くならないとうまく炊けない「炊飯器少女コメコ」1巻を読んでみた【家電マンガ】', 'パナソニックのデジカメに新色!「LUMIX DMC-GF3」と「LUMIX DMC-G3」に新色シェルホワイトが登場', '「おもしろそう!」「見た目がおしゃれ!」女子中高生が1番欲しいのはiPhoneだった【話題】', 'Googleにユーザー属性がバレ過ぎて恐怖の声', 'ポテンシャルが高い人はココが違う!-人事担当者がこっそり教える採用ウラ話 vol.2', '驚異の重低音ポータブルプレーヤーCreative Zen X-F13【売れ筋チェック】', 'まだスーパーマルチなアナタに! 薄型のポータブルBDドライブが登場', 'NTTドコモ、コンパクトなXi対応全部入りスマホ「Optimus it L-05D」を6月30日に発売予定!6月22日から事前予約開始', 'おぎやはぎ・小木のAKB48非難に小林よしのり氏が猛反撃', '今もっとも注目の「Ultrabook」が20台貰えるレビューアー募集!活用サイト「Ultrabooker.jp」がオープン記念', '学生は要チェック! アップルがMacを買うと1万円分のアプリが買えるキャンペーンをスタート', 'ついにターミネーターの世界が現実に!? —2012年中にグーグルがサングラス型のコンピューターを発売予定【話題】', '独女的映画レビュー vol.14 『私がクマにキレた理由(ワケ)』']
# 32
# 独女の疑問......結婚後のマイホーム購入は当たり前?
# ---------------
#  この記事では、主に既婚者の女性に焦点を当てて、結婚後にマイホームを購入する理由や背景について述べられています。記事中では、3人の既婚女性の体験談が紹介されています。
#
# 1人目の女性は、子供が生まれた
# ===============
# 人生観が変わる!? 一度は行ってみたい世界のあの場所!
# ---------------
#  提示された記事の内容を要約し、結果のみを出力します。
#
#
# ・トルコのカッパドキアにある洞窟ホテルは、不思議な風景を楽しめる世界遺産で、独特な作りの豪華なホテル。日本人に友好的であるが、買い物には注意
# ===============
# iTunes史上最高のダウンロード数を記録した『ダークナイト ライジング』の予告映像を公開
# ---------------
#  記事の要約:
#  映画「ダークナイト ライジング」の予告映像がiTunesで1250万ダウンロードを記録し、歴代最高となった。この作品はバットマンシリーズの最終章であり、監督はクリストファー・ノーラン
# ===============
# 映画『荒川アンダー ザ ブリッジ』より“俺のスターアルバム”発売決定
# ---------------
#  『荒川アンダー ザ ブリッジ』は、中村光による漫画作品で、実写映画が2012年2月に公開されました。映画公開に合わせ、キャラクター「星」をモチーフにしたコンピレーション・アルバム『俺のスターアルバム
# ===============
# 3D全盛の時代に、白黒のサイレント映画『アーティスト』が評価される理由
# ---------------
#  要約:
# 「第84回アカデミー賞」で最多5部門を受賞した「アーティスト」は、サイレント、モノクロの映画で、セリフや色のない映像美を特徴としている。この映画は、主人公の俳優と犬の関係を描いたロマンティッ
# ===============
# 【元気東北・福島編】雪国を南国にした福島人の底力
# ---------------
#  「元気東北・福島編」の記事の要約は、以下の通りです。
#
# 映画「フラガール」は、閉山の危機にあった福島の炭鉱町をハワイアンセンターの設立によって救おうとする実話を元にした作品で、常識に囚われずに挑戦す
# ===============
# 女子力アップの簡単“キメ技”術指南 vol.2
# ---------------
#  この記事の要約は以下の通りです。
#
# この記事では、初秋を感じられるテーブルコーディネートの方法を紹介しています。
#
# まず、「魔法の葉っぱ」を料理に添えることが提案されています。これは栗の葉など秋の木
# ===============
# 謎のモザイク美女の正体はAKB48の篠田麻里子、声優挑戦は成功するか
# ---------------
#  記事の内容を要約します。
#
# ・映画「TIME/タイム」の日本語吹き替え版の声優として、AKB48の篠田麻里子が選ばれました。
# ・映画公開に先立って、公式ホームページ上で、正体を伏せた「謎のモザイク美
# ===============
# 脳を刺激する“極上のミステリー”が誕生!攻防戦を繰り広げる予告映像が公開
# ---------------
#  この文章では、映画『推理作家ポー 最期の5日間』のあらすじとキャストが紹介されています。物語は、1849年のアメリカ・ボルチモアを舞台に、推理作家エドガー・アラン・ポーが、自身の小説を模倣した殺人事
# ===============
# 日ハム・大嶋匠、連日の活躍にも「少年野球以来なので、野球をするのは」
# ---------------
#  北海道日本ハムファイターズの大嶋匠選手は、TBSの枡田絵理奈アナウンサーのインタビューに応じました。大嶋選手はソフトボール出身で、先の紅白戦でプロ初打席に立ち、初本塁打を記録しました。その翌日にも安
# ===============
# 台湾でHappy開運の旅 絶品豆乳と極楽マッサージでリフレッシュ
# ---------------
#  この記事では、台湾旅行において食と癒しをテーマにした旅程の最終日が紹介されています。朝は老舗の朝食専門店「阜杭豆漿」で豆乳料理を楽しみ、その後「Hair Mall 翠姿媚店」でヘッドスパを受け、心身
# ===============
# 専用のPlayキーを持つ防水ミュージックプレイヤー スマートフォン「AQUOS PHONE st SH-07D」【レビュー】
# ---------------
#  この文章は、スマートフォン「AQUOS PHONE st SH-07D」のレビュー記事です。このスマートフォンは、コンパクトで防水・防塵機能を持ち、音楽再生に特化した「Playキー」を搭載しています
# ===============
# ネットで悪口を書かれたらどうすればいい?
# ---------------
#  記事の内容を要約します。
#
#
# 沙織さんという女性が、自分の名前をネット検索したところ、会ったことのある人のブログに勝手に写真がアップされていたという経験をしました。このようにネットで悪口を書かれた場
# ===============
# 【オトナ女子のリアルな悩み】転職を繰り返してしまう40代女子の本音
# ---------------
#  この記事では、自身の性格により転職を繰り返してしまう40代の女性が、電話占い師に相談し、アドバイスを受ける様子が書かれています。相談者の女性は、周囲の目を気にしすぎてしまい、自分に自信が持てないこと
# ===============
# 待望のEOS 5D Mark III、動画の進化のポイントは?【ビデオSALON】
# ---------------
#  与えられた文章の要約は、以下の通りです。
#
# EOS 5D Mark IIIは、キヤノンのデジタル一眼レフカメラで、フルサイズCMOSセンサー、DIGIC 5+映像エンジンを搭載しています。動画撮影に
# ===============
# ブランド牛のニューフェイス、“恵比寿牛”ってどんなお肉?
# ---------------
#  この文章の要約は以下の通りです。
#
# ウェスティンホテル東京で、「恵比寿牛」という新たなブランド牛の提供が開始されます。恵比寿牛は、鹿児島県の大規模農場「のざき牧場」で育てられた黒毛和牛を使用し、ウェ
# ===============
# 落合元監督、“内川へのクレーム”に言及 「もし専門家に言わせたら・・・」
# ---------------
#  記事では、日本シリーズのある場面で、中日ドラゴンズの落合博満元監督が、福岡ソフトバンクホークスの内川聖一選手のバットに巻かれたグリップにクレームをつけたことについて、その真意を落合監督本人が説明して
# ===============
# 無職ランナーをオリンピックへ! プレアカ1か月分でスポンサーになれる
# ---------------
#  この記事では、東京マラソンで脚光を浴びたマラソンの藤原新選手が、フリーで競技を続けるために設立した「株式会社藤原新」において、ニコニコ動画のプレミアム会員による個人スポンサーを募集していることが述べ
# ===============
# 【スナップレポート】東京ガールズコレクション 2011 藤井リナ編
# ---------------
#  「東京ガールズコレクション 2011」の藤井リナに関するスナップレポートの要約は以下の通りです。
#
# 藤井リナは、日本のファッションモデル、アーティスト、歌手として知られており、東京ガールズコレクショ
# ===============
# ご飯炊けまくりマシタ! 仲良くならないとうまく炊けない「炊飯器少女コメコ」1巻を読んでみた【家電マンガ】
# ---------------
#  「炊飯器少女コメコ」は、芳文社のまんがホーム・まんがタイムジャンボで連載中の4コマ漫画で、主人公のたけるが母親から送られてきた人型の炊飯器・コメコとの生活を描いています。コメコは育成型の炊飯器で、た
# ===============
# パナソニックのデジカメに新色!「LUMIX DMC-GF3」と「LUMIX DMC-G3」に新色シェルホワイトが登場
# ---------------
#  パナソニックのミラーレス一眼カメラ「LUMIX DMC-GF3」と「LUMIX DMC-G3」に新たにシェルホワイトの新色が登場します。
#
# 「LUMIX DMC-GF3」は、コンパクトでタッチパネル
# ===============
# 「おもしろそう!」「見た目がおしゃれ!」女子中高生が1番欲しいのはiPhoneだった【話題】
# ---------------
#  ふみコミュニケーションズの調査によると、女子中高生が最も欲しいスマートフォンはiPhoneで、人気の理由は、「いろいろなことができておもしろそう」、「おしゃれ」、「かっこいい」などのイメージによるも
# ===============
# Googleにユーザー属性がバレ過ぎて恐怖の声
# ---------------
#  Googleがユーザーに表示する広告のために、cookie履歴からユーザーの属性を判定しているが、その精度の高さに驚きの声が上がっている。年齢や性別だけでなく興味のあるカテゴリーまで判定され、一部の
# ===============
# ポテンシャルが高い人はココが違う!-人事担当者がこっそり教える採用ウラ話 vol.2
# ---------------
#  記事の内容を要約します。
#
#
# ポテンシャルが高い人を採用するためには、これまでの経験をきちんと説明できること、これからの目的やそのプロセスが明確であることが重要だと、通信関連会社の採用担当者の白石
# ===============
# 驚異の重低音ポータブルプレーヤーCreative Zen X-F13【売れ筋チェック】
# ---------------
#  新製品のCreative Zen X-F13ポータブル音楽プレーヤーは、付属のヘッドフォンがベースとなっているEP-630が高音質であることが特徴です。このプレーヤーは、CD音質を維持し、圧縮された
# ===============
# まだスーパーマルチなアナタに! 薄型のポータブルBDドライブが登場
# ---------------
#  この記事ではアイ・オー・データ機器が発売した薄型ポータブルBDドライブ「BRP-U6Cシリーズ」が紹介されています。主な特徴は以下の通りです。
#
# ・薄くて軽い（厚さ14mm、重さ約300g）
# ・四角
# ===============
# NTTドコモ、コンパクトなXi対応全部入りスマホ「Optimus it L-05D」を6月30日に発売予定!6月22日から事前予約開始
# ---------------
#  NTTドコモは、LG製のスマートフォン「Optimus it L-05D」を6月30日に発売する。事前予約は6月22日から受け付ける。「Optimus it L-05D」は、Xi対応、おサイフケータ
# ===============
# おぎやはぎ・小木のAKB48非難に小林よしのり氏が猛反撃
# ---------------
#  この記事では、ロンドンオリンピックで金メダルを獲得した体操の内村航平選手と、AKB48の総選挙を比較して「AKBの総選挙以上のプレッシャーがある」と発言したAKB48の高橋みなみさんに対して、おぎや
# ===============
# 今もっとも注目の「Ultrabook」が20台貰えるレビューアー募集!活用サイト「Ultrabooker.jp」がオープン記念
# ---------------
#  記事の要約:
#
# * Ultrabook(TM)とは、Intelが提唱する基準を満たした高性能かつ低価格なノートPCのことで、MacBook Airとは異なる。
# * 各社から発売されているUltrab
# ===============
# 学生は要チェック! アップルがMacを買うと1万円分のアプリが買えるキャンペーンをスタート
# ---------------
#  「新学期を始めよう」キャンペーンでは、学生・教職員価格でMacを購入すると、1万円分の「新学期を始めよう」カードがもらえます。このキャンペーンは5月11日までです。新しいMacの購入を検討している学
# ===============
# ついにターミネーターの世界が現実に!? —2012年中にグーグルがサングラス型のコンピューターを発売予定【話題】
# ---------------
#  Googleは2012年末までに、サングラス型のコンピューターを発売予定である。このサングラスは、3Gまたは4Gで通信可能で、ユーザーは頭の傾きや声で操作できる。プラットフォームはAndroidで、
# ===============
# 独女的映画レビュー vol.14 『私がクマにキレた理由(ワケ)』
# ---------------
#  この記事は、映画「私がクマにキレた理由」のあらすじ、登場人物、テーマについてのレビューです。主人公のアニーは、大学を優秀な成績で卒業し、ゴールドマン・サックスの面接を受けるも、自分のアイデンティティ
# ===============
# 45/47
#
# ['リアルでも役立つ美味しいビールの注ぎ方をマスターできる!「ビールで黄金比率」【iPhoneアプリ】', '働く女子の疲れを優しくケアしよう。伝統の健康法「お灸」教室をお試し', '日本スケート連盟のキム・ヨナ締め出しに「当然」の声', '脱原発で仕事激減の山本太郎! 収入は10分の1だが、本も出版で以前よりテレビに出てるかも?【話題】', '<コラム>長尺ドライバーで飛ばそう【ゴルフ特集】', '「SATC2」がついに世界初上映! ワールドプレミアに5,000人熱狂', '失業率の高さも原因か...アメリカの年末商戦、今年は家電も超激安!【話題】', 'AKB48篠田麻里子のコスプレ写真を公開!ナースにビールガールなど七変化', 'スギちゃん、本音明かす「ワイルドだけど、嫌われたくないんですよ」', '【終了しました】白金のシンボル的レストラン「BLUE POINT」のペアディナーチケット(1ドリンク付き)が当たるツイッターキャンペーン実施中!!', '【Sports Watch】亀田大-坂田決定、“負けたら坊主”に「私がなります」', '「はやぶさ」が“かなり飛び出る3D駅貼ポスター”、都内に登場', '同価格帯でネットブックより強力なベストセラーモバイルノート【新生活特集】', 'タダ者じゃない!7インチタブレット「eden TAB」の魅力をさぐる', '大津市いじめ問題、病院に怪情報を信じたネット住民の抗議電話が殺到', '彼女の香りは、柔軟剤の香り', '人気ブランド「トリー バーチ」、初の海外進出は日本!5月12日オープン', '【週末映画まとめ読み】『となりのトトロ』の驚きの裏設定を知っていますか?', '「自分でいうのもなんですけど・・・」体操・田中理恵、急成長の理由明かす', '目に見えない「透明マント」光学素子が、 映像機器を変える【サイエンスニュース】', '【話題】電気ポット?電気ケトル?節電に効果的な「湯沸かし家電」とは', 'NTTドコモ、月額420円で約500作品が見放題の「アニメストア」をオープン', 'エストネーションに聞く「デキルオトコの新作スーツの着こなし方」 【新生活特集】', '今度は大丈夫? iPhoneで24時間無料のWi-Fi!「LAWSON Wi-Fiサービス」が大幅アップデート', 'Facebookページの活用方法 - 転職活動に役立つ!ソーシャルメディア活用術 vol.5', 'ありそうでなかった便利グッズ!iPad2用バッテリー内蔵ケース', 'ジョニデ&バートン監督が贈る“フツー”じゃないファミリーとは?', '【話題】デリケートなスマホの扱い要注意! 破損の大きな原因と対策', '新境地開拓か、奇行か? 鬼束ちひろ′′暴走′′の行く末', 'Time-Lapse(微速度)撮影ができるカメラ! COMPTEX TAIPEIで見つけたオモシロガジェット【デジ通】', 'アントニオ・バンデラスが「スマイルを届ける」と日本にメッセージ', '【iPhone版】新しくなった♪ Peachyアプリの使い方']
# 32
# リアルでも役立つ美味しいビールの注ぎ方をマスターできる!「ビールで黄金比率」【iPhoneアプリ】
# ---------------
#  この記事は、iPhoneアプリ「ビールで黄金比率」を紹介しています。このアプリは、ビールを黄金比率（７：３）で注ぐゲームで、注ぐ技術を鍛えることができます。ユーザーは、ジョッキにビールと泡を注ぎ、そ
# ===============
# 働く女子の疲れを優しくケアしよう。伝統の健康法「お灸」教室をお試し
# ---------------
#  この記事では、働く女性がゴールデンウィーク明けの疲れをケアするために、伝統的な健康法であるお灸を試すことを勧めています。せんねん灸の「お灸ルーム」で開催された「お灸教室」では、参加者がお灸に使われる
# ===============
# 日本スケート連盟のキム・ヨナ締め出しに「当然」の声
# ---------------
#  「週刊新潮」の記事では、日本スケート連盟がキム・ヨナを日本のアイスショーに出演させないことを報じており、その理由はキム・ヨナと日本人選手の共演を同連盟が拒否しているためとされています。ネット上では、
# ===============
# 脱原発で仕事激減の山本太郎! 収入は10分の1だが、本も出版で以前よりテレビに出てるかも?【話題】
# ---------------
#  東日本大震災の後、脱原発活動をしている山本太郎は、以前の芸能活動に比べて収入が激減しているが、脱原発の活動によりテレビ出演などのメディア露出は増加している。著書「ひとり舞台—闘う役者の真実」も発売さ
# ===============
# <コラム>長尺ドライバーで飛ばそう【ゴルフ特集】
# ---------------
#  与えられた文章の要約と結論を以下に示します。
#
#
# ゴルフクラブのテクノロジーの進歩により、近年ドライバーの飛距離が大幅に伸びました。特に、チタンドライバーの登場により、パーシモン時代と比較して、ヘッ
# ===============
# 「SATC2」がついに世界初上映! ワールドプレミアに5,000人熱狂
# ---------------
#  「セックス・アンド・ザ・シティ2」の世界初上映が、ニューヨークで行われ、5000人のファンが集まりました。サラ・ジェシカ・パーカーをはじめとする出演者がファンサービスを行い、映画の公開を楽しみにして
# ===============
# 失業率の高さも原因か...アメリカの年末商戦、今年は家電も超激安!【話題】
# ---------------
#  アメリカの今年の年末商戦では、家電製品も例年にない大幅な値引きが行われており、例えば、98ドルの19型液晶テレビや、シャープの42型液晶テレビが199.99ドルで販売された。このような値引きの背景に
# ===============
# AKB48篠田麻里子のコスプレ写真を公開!ナースにビールガールなど七変化
# ---------------
#  この記事は、11月3日公開の映画「サラリーマンNEO 劇場版(笑)」の出演者である篠田麻里子のコスプレ姿の写真を公開したものです。篠田はこの映画の中で、昼は会社の受付嬢、夜は転職バーで働くOL・マオ
# ===============
# スギちゃん、本音明かす「ワイルドだけど、嫌われたくないんですよ」
# ---------------
#  要約します。
# お笑い芸人のスギちゃんがブレイクするまで、コンビでの活動やさまざまなキャラクター変更などの苦労があったと明かしています。また、先輩芸人のダウンタウンを尊敬しているというエピソードを、芸
# ===============
# 【終了しました】白金のシンボル的レストラン「BLUE POINT」のペアディナーチケット(1ドリンク付き)が当たるツイッターキャンペーン実施中!!
# ---------------
#  提示された文章の要約および結果は以下の通りです。
#
#
# 本文では、白金のシンボル的なレストラン「BLUE POINT」のペアディナーチケット（1ドリンク付き）が当たるツイッターキャンペーンについての告
# ===============
# 【Sports Watch】亀田大-坂田決定、“負けたら坊主”に「私がなります」
# ---------------
#  ボクシングのWBA世界フライ級王者・亀田大毅と元同級王者・坂田健史のタイトルマッチが9月25日に開催決定した。対戦決定に関連して、坂田の所属する協栄ジムの金平桂一郎会長が、亀田大毅の印象や当時のエピ
# ===============
# 「はやぶさ」が“かなり飛び出る3D駅貼ポスター”、都内に登場
# ---------------
#  映画「おかえり、はやぶさ」の公開に先立ち、「はやぶさ」を題材にした“かなり飛び出る3D駅貼りポスター”が作成され、5都市での掲出が開始されました。このポスターでは、専用のメガネを使用することで、「は
# ===============
# 同価格帯でネットブックより強力なベストセラーモバイルノート【新生活特集】
# ---------------
#  この記事は、ASUS UL20Aというノートパソコンについて述べています。このノートパソコンは、一般的なネットブックよりも高性能であり、同価格帯の製品の中では隠れたベストセラーとなっています。以下に
# ===============
# タダ者じゃない!7インチタブレット「eden TAB」の魅力をさぐる
# ---------------
#  要約:
# Mobile In Styleから2012年3月3日に発売される7インチタブレット「eden TAB Wi-Fi ソフト搭載モデル」は、キングソフト社のオフィスソフト、セキュリティソフト、オ
# ===============
# 大津市いじめ問題、病院に怪情報を信じたネット住民の抗議電話が殺到
# ---------------
#  大津市のいじめ問題に関連して、済生会滋賀県病院に怪情報が流れ、抗議電話が殺到し、病院の診療業務に支障が出ている。病院側は、怪情報を否定し、良識ある言動を求める文書を公表した。この問題は、ネット掲示板
# ===============
# 彼女の香りは、柔軟剤の香り
# ---------------
#  記事では、最近の柔軟剤は香りにこだわりのあるものが増え、洗濯後の香りで女性が幸せを感じることができる一方で、香りに対する好みは人それぞれであることが述べられています。また、柔軟剤の香りが原因で気分が
# ===============
# 人気ブランド「トリー バーチ」、初の海外進出は日本!5月12日オープン
# ---------------
#  要約: ニューヨーク発のライフスタイルブランド、トリー バーチは、オンラインショップを日本に初オープンしました。これは、トリー バーチが本国以外で開設した最初のオンラインストアです。アパレル、ハンド
# ===============
# 【週末映画まとめ読み】『となりのトトロ』の驚きの裏設定を知っていますか?
# ---------------
#  『となりのトトロ』には驚きの裏設定があり、メイとサツキの父親は当初死んでいる設定だったが、今は単に仕事で海外に行っているだけという設定に変更されている。
# ===============
# 「自分でいうのもなんですけど・・・」体操・田中理恵、急成長の理由明かす
# ---------------
#  記事では、体操の田中理恵選手のインタビュー内容が書かれています。
#
# 今年のNHK杯で、ロンドンオリンピック出場を決めた田中選手は、オリンピックではメダルに近い色を獲りにいきたいと語りました。
#
# 体操
# ===============
# 目に見えない「透明マント」光学素子が、 映像機器を変える【サイエンスニュース】
# ---------------
#  透明マントのような光学素子が開発されました。この素子は、プラズモニック・メタマテリアルと呼ばれる人工光学材料で作られており、特定の条件下で光を散乱させずに透過させることができます。これにより、光セン
# ===============
# 【話題】電気ポット?電気ケトル?節電に効果的な「湯沸かし家電」とは
# ---------------
#  記事の要約は以下の通りです。
#
# 魔法瓶と電気ポットの特徴を比較し、それぞれのメリットとデメリットを説明しています。節電を考えた場合、家族構成や生活スタイルによって、適切な製品が異なるとしています。具
# ===============
# NTTドコモ、月額420円で約500作品が見放題の「アニメストア」をオープン
# ---------------
#  「ドコモ・アニメストア」がアニメ見放題サービスを開始しました。月額420円で約500作品10,000話のアニメをドコモのスマートフォンやタブレットで見ることができます。テレビ放送中のアニメも、放送後
# ===============
# エストネーションに聞く「デキルオトコの新作スーツの着こなし方」 【新生活特集】
# ---------------
#  この記事の要約は以下の通りです。
#
# エストネーション六本木ヒルズ店の森田敏裕さんによると、2010年春夏のファッション業界のトレンドは、クラシックとリラックスの融合です。カラーはグレーが流行で、無地
# ===============
# 今度は大丈夫? iPhoneで24時間無料のWi-Fi!「LAWSON Wi-Fiサービス」が大幅アップデート
# ---------------
#  提供された文書の要約は、ローソンがiPhone用のアプリケーションをアップデートし、以前の問題を解決した上で、「LAWSON Wi-Fi」への接続をより簡単かつ便利にしたことを示しています。このサー
# ===============
# Facebookページの活用方法 - 転職活動に役立つ!ソーシャルメディア活用術 vol.5
# ---------------
#  与えられた文章の要約です。
#
# Facebookページとは企業や個人が情報発信するための独自のページで、個人ユーザーが友達追加することで、更新情報などを受け取ることができる。Facebookページを「
# ===============
# ありそうでなかった便利グッズ!iPad2用バッテリー内蔵ケース
# ---------------
#  この記事で紹介されている商品は、「Portable Power Bank with Smart Cover for iPad2」というiPad2用のバッテリー内蔵ケースです。以下に要点をまとめました
# ===============
# ジョニデ&バートン監督が贈る“フツー”じゃないファミリーとは?
# ---------------
#  要約:
#
# ダーク・シャドウズは、ティム・バートンが監督し、ジョニー・デップが主演する映画で、1960年代から1970年代の人気テレビ番組を原作としています。物語は、魔女によって吸血鬼にされたバーナバ
# ===============
# 【話題】デリケートなスマホの扱い要注意! 破損の大きな原因と対策
# ---------------
#   一番多いスマートフォンの破損理由は「水没させた」で、全体の36.8%の人が回答しています。従来の携帯電話と比較しても、水没が半分以上の理由となっており、スマートフォンの水没のしやすさが伺えます。
#
# ===============
# 新境地開拓か、奇行か? 鬼束ちひろ′′暴走′′の行く末
# ---------------
#  記事の内容を要約すると、鬼束ちひろが2013年にニコニコ生放送に出演した際に、その奇行ぶりが話題になったというものです。彼女の風貌や言動が以前とは大きく変わり、厚化粧で派手な服装、過激な行動や発言が
# ===============
# Time-Lapse(微速度)撮影ができるカメラ! COMPTEX TAIPEIで見つけたオモシロガジェット【デジ通】
# ---------------
#  この記事では、COMPTEX TAIPEIで展示されたタイムラプスカメラ「TLC200」について説明されています。「TLC200」は、植物の成長や雲の動きなどを、長時間かけて撮影するタイムラプス撮影
# ===============
# アントニオ・バンデラスが「スマイルを届ける」と日本にメッセージ
# ---------------
#  『シュレック』シリーズのスピンオフ映画『長ぐつをはいたネコ』のロサンゼルス・プレミアが開催され、主演のアントニオ・バンデラスやサルマ・ハエック、ザック・ガリフィアナキスらが登場し、日本へ向けて応援メ
# ===============
# 【iPhone版】新しくなった♪ Peachyアプリの使い方
# ---------------
#  この文章では、新しくなったiPhone版Peachyアプリの便利な機能が紹介されています。以下に主な機能をまとめました。
#
#
# 1.お気に入り機能:トップページの「おもしろそうな記事」をワンタップで「
# ===============
# 46/47
#
# ['年賀状に見るDQNネーム最前線']
# 1
# 年賀状に見るDQNネーム最前線
# ---------------
#  記事の内容を要約します。
#
# 近年、年賀状に子供の変わった名前が増え、それらはDQNネームと呼ばれています。記事では周囲の友人にリサーチした結果を紹介していますが、以下のような男女の子供の名前が挙げら
# ===============
# ---finish---
