# %%
# クラス名のリスト
labels = ['独女通信', 'IT ライフハック', '家電チャンネル', 'livedoor HOMME', 'MOVIE ENTER', 'Peachy', 'エスマックス', 'Sports Watch', 'トピックニュース']

cm = [[[94, 0, 0, 1, 0, 2, 0, 1, 0], [0, 93, 1, 0, 0, 0, 1, 0, 0], [0, 0, 82, 1, 0, 2, 0, 1, 0], [1, 2, 1, 39, 3, 1, 0, 1, 0], [0, 0, 0, 0, 77, 0, 0, 0, 0], [1, 0, 0, 1, 0, 95, 0, 0, 0], [0, 1, 0, 0, 0, 0, 79, 0, 0], [0, 0, 0, 0, 0, 0, 0, 79, 0], [0, 0, 0, 0, 0, 0, 0, 1, 75]]]
cm_pqrs = [[[95, 0, 0, 0, 0, 2, 0, 1, 0], [0, 93, 1, 0, 0, 0, 1, 0, 0], [0, 0, 83, 0, 0, 2, 0, 1, 0], [1, 3, 1, 37, 4, 2, 0, 0, 0], [1, 0, 0, 0, 75, 1, 0, 0, 0], [2, 0, 0, 0, 0, 95, 0, 0, 0], [0, 1, 0, 0, 0, 0, 79, 0, 0], [0, 0, 0, 0, 0, 0, 0, 79, 0], [0, 0, 0, 0, 0, 0, 0, 1, 75]]]
cm_jurai = [[[95, 0, 0, 1, 0, 1, 0, 1, 0], [0, 94, 1, 0, 0, 0, 0, 0, 0], [0, 0, 84, 0, 0, 1, 0, 1, 0], [1, 3, 1, 38, 3, 1, 0, 1, 0], [1, 0, 0, 1, 74, 1, 0, 0, 0], [1, 1, 0, 3, 2, 90, 0, 0, 0], [0, 2, 0, 0, 0, 1, 77, 0, 0], [0, 0, 0, 0, 0, 0, 0, 77, 2], [0, 0, 0, 0, 0, 0, 0, 1, 75]]]

# %%
# 日本語フォントのインストール
# !apt-get -y install fonts-noto-cjk
# !apt-get -y install fonts-ipafont-gothic
# !pip install japanize_matplotlib
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   fonts-noto-cjk-extra
# The following NEW packages will be installed:
#   fonts-noto-cjk
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 61.2 MB of archives.
# After this operation, 93.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-cjk all 1:20220127+repack1-1 [61.2 MB]
# Fetched 61.2 MB in 4s (16.4 MB/s)
# Selecting previously unselected package fonts-noto-cjk.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../fonts-noto-cjk_1%3a20220127+repack1-1_all.deb ...
# Unpacking fonts-noto-cjk (1:20220127+repack1-1) ...
# Setting up fonts-noto-cjk (1:20220127+repack1-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np
import japanize_matplotlib

# %%
# 図のサイズを設定
plt.figure(figsize=(8, 6))
sns.set(font='IPAexGothic')
# seabornを使って混合行列をヒートマップで可視化
sns.heatmap(cm_jurai[0], annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
# ラベルの設定
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 表示
plt.show()

# %%
# 図のサイズを設定

plt.figure(figsize=(8, 6))
sns.set(font='IPAexGothic')
# seabornを使って混合行列をヒートマップで可視化
sns.heatmap(cm_pqrs[0], annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
# ラベルの設定
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 表示
plt.show()

# %%
cm_a5 = [[[94, 0, 0, 1, 0, 2, 0, 1, 0], [0, 95, 0, 0, 0, 0, 0, 0, 0], [0, 0, 84, 0, 0, 1, 0, 1, 0], [1, 3, 1, 38, 3, 1, 0, 1, 0], [1, 0, 0, 1, 74, 1, 0, 0, 0], [2, 0, 0, 1, 0, 94, 0, 0, 0], [0, 1, 0, 0, 0, 0, 79, 0, 0], [0, 0, 0, 0, 0, 0, 0, 78, 1], [0, 0, 0, 0, 0, 0, 0, 1, 75]]]

# 図のサイズを設定

plt.figure(figsize=(8, 6))
sns.set(font='IPAexGothic')
# seabornを使って混合行列をヒートマップで可視化
sns.heatmap(cm_a5[0], annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
# ラベルの設定
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 表示
plt.show()
